# %% [markdown]
# # Debt Data Time Series

# %% [markdown]
# This script seeks to grab the subset of relevant variables from each year, so that we have a set across all years that can be readily merged with the TEL/ACS data.

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import glob

# %% [markdown]
# ## What are the common variables?

# %% [markdown]
# The first thing we will do is see if we can get what we need from just the common variables across all sets.  There are a few reasons why variables may not align every year:
#
# 1. Reuters doesn't offer the entire set of variables every year;
# 2. Variable names with long words may have been hyphenated in different ways across years;
# 3. If variables appeared more than once, the parsing routine appended the variable position to the name to create a unique variable.  If the position varies across years, so will the variable name.
#
# To grab the columns in lightweight fashion, we will just read in the first couple lines for each set.

# %%
files[0][13:-4]
# Out:
# '1988to1989'

# %%
#Grab list of files
files=glob.glob('../debt_data/*.csv')

#Create a dictionary to hold columns from each year
col_dict={}

#For each file...
for f in files:
    #...read in the first couple rows...
    tmp_df=pd.read_csv(f,nrows=2)
    #...capture the columns...
    col_dict.update({f[13:-4]:list(tmp_df.columns)})
    #...and dump the partial data set
    del tmp_df
    
#Create a container for the variable sets within each file
var_sets=[]

#For each file...
for f in col_dict.keys():
    #...add the variable set to var_sets
    var_sets.append(set(col_dict[f]))
    
#Capture the intersection of variables across all years
common_vars=sorted(list(set.intersection(*var_sets)))

print 'There are '+str(len(common_vars))+' variables common to all sets.'
print common_vars
# Out:
# There are 254 variables common to all sets.
# ['# of Mgrs', '$ Amount of Highest Cpn Maturity', '144A FLAG', '501c3', '8-Digit CUSIP25', '8-Digit CUSIP26', 'Accumulator Amt ($ Mil)', 'All Use of Proceeds (Code)', 'All Use of Proceeds (Desc)', 'All Use of Proceeds (Number)', 'Amount at Maturity ($ mils)', 'Amount of Final Maturity ($mils)', 'Amount of Issue ($ mils)', 'Amount of Maturity ($ mils)', 'Ant- ici- pa- tion Type', 'Asset Backed Indicator Flag (Y/N)', 'Auction Rate', 'Aver- age Life', 'Average Take Down', 'Bank Qual', 'Beginning Price/ Yield', 'Beginning Serial Coupon', 'Beginning Serial Maturity', 'Bid', 'Bk Elig', 'Bk En- try', 'Bnk Mgd', 'Bond Buyer ALL UOP', 'Bond Buyer GO Index', 'Bond Buyer Region118', 'Bond Buyer Region119', 'Bond Buyer Rev. Index', 'Bond Buyer UOP142', 'Bond Buyer UOP143', 'Bond Buyer UOP30', 'Bond Counsel Deal(Y/N)', 'CD-ROM Number', 'CUSIP of Insti- tutional Backer', 'Call Date', 'Call Issue', 'Call Price', 'Callable at Par', 'Co-Managers', 'Comb. Gross Spread', 'Comm- ercial Paper', 'Comp Amount of Issue ($ mils)', 'Conversion Date (Maty)', 'Corp orate Backed', 'Corporate or Institutional Backer', 'County', 'Coupon Maturity', 'Coupon Rate', 'Coupon Type67', 'Coupon Type69', 'Coupon Type70', 'Coupon of Fin Maty', 'Coupon of Maturity', 'Cpn Type', 'Credit Enhance ment Type71', 'Credit Enhance ment Type72', 'Credit Enhancer73', 'Credit Enhancer74', 'Credit Enhancer75', 'Cusip', 'DALCOMP Number', 'DOUBLE BARRELED', 'DTC Elig', 'Date Issue Added', 'Dated Date17', 'Dated Date18', 'Days to Delivery Calculator', 'Dealno of Refunded Issue', 'Deals with Profors/Obligors (Y/N)', 'Delivery Date', 'Denomination', 'Deriv- ative Type', 'Disclosure Counsel', 'Disclosure Counsel Deal(Y/N)', 'Edtype', 'Electronic Bidding System', 'Electronic Bidding Y/N Flag', 'Email Address', 'Ending Price/ Yield', 'Ending Serial Coupon', 'Ending Serial Maturity', 'Ending Serial Price/ Yield', 'Expenses', 'Extra ord. Redem', 'FITCH Rating', 'Fiche #', 'Final Mat. Year', 'Final Maturity', 'Financial Advisor Deal(Y/N)', 'Financial Advisor106', 'Financial Advisor107', 'Financial Advisor108', 'First Call Date', 'First Interest Payment Date', 'First Sinking Fund Date', 'Fitch Underlying Rating', 'Fitch Underlying Short Rating', 'Fitch109', 'Fitch110', 'Fitch112', 'Fitch113', 'General Use of Proceeds', 'Genl Use of Procd', 'Gross Spread', 'Highest Coupon', 'Hosp- ital Code', 'Hospital Code', 'Industry', 'Initial Call Price', 'Initial Put Date', 'Insured Amount', 'Issue Dated Date', 'Issue Description', 'Issue Number', 'Issuer', 'Issuer Cusips', 'Issuer Type', 'Issuer Type Description', 'Issuer Website', "Issuer's Counsel134", "Issuer's Counsel135", "Issuer's Counsel136", 'Joint Action Issuer', 'Lead Manager', 'Lease Type', 'Letter of Credit Expiration Date (Maty)', 'Main Use of Proceeds', 'Main Use of Proceeds (Code)', 'Main Use of Proceeds (Number)', 'Manager Allocation Amount (US$ Mil)', 'Managers219', 'Managers28', 'Marketplace', 'Marketplace Code', 'Master Deal Type', 'Maturity Amount', 'Maturity Date5', 'Maturity Date7', 'Maturity Year', 'Maturity16', 'Maturity6', 'Maty of Highest Cpn Maty', 'Mgmnt Fee', 'Minority Firm as Bond Counsel Flag (Y/N)', 'Minority Firm as Co-Mgr', 'Minority Manager', 'Mlt Sys Hsp', 'Moody Rating156', 'Moody Rating159', 'Moody S&P plit Rated', 'Moody Short Rating', "Moody's Long Term Rating", "Moody's Underlying Long Term Rating", 'Mtg Loan Rate', 'Nation Code', 'Nation169', 'Nation170', 'Net Proceeds', 'Net nterest Cost', 'Notes (1)', 'Notes (2)', 'Notes (3)', 'Number', 'Number of Co-Lead Managers', 'OS tatus', 'Off- Type', 'Other Interest Cost', 'Other Interest Cost Type', 'PENSION FLAG', 'Par Amount per Book Runner', 'Paying Agent (Y/N)', 'Paying Agent182', 'Paying Agent183', 'Paying Agent184', 'Phone Number', 'Pooled Issue', 'Pre-Ref Date', 'Pre-Ref Status', 'Preliminary Issue Flag', 'Price/ Yield of Maturity', 'Principal Amount', 'Project191', 'Project192', 'Prov. or Cond. Rating', 'Put Freq', 'Qualified Zone Academy Bonds (Y/N) Flag', 'Ra ...

# %% [markdown]
# Ok, we are looking for aggregations of debt by county.  In particular, we want to capture activity by concepts:
#
# 1. Type of Debt (General Obligation or Revenue; latter can be split by )
# 2. Issuer Type (General purpose gov, school district, special district, or private entity)
# 3. Purpose of the Issue
# 4. Volume of Issue
#
# For the latter two, we also want variables that split out GO versus revenue bonds.  For example, we would want to know the volume of GO debt issued by general purpose jurisdictions, or the revenue debt issued in service of transportation infrastructure.  The following table maps concepts to variables.
#
# Concept|Variable|Possible Values
# -------|--------|---------------
# Debt Type|`Security Type`| GO<br>RV
# Issuer Type|`Issuer Type Description`|District<br>City, Town Vlg<br>Local Authority<br>State Authority<br>County/Parish<br>College or Univ<br>State/Province<br>Direct<br>Indian Tribe<br>Co-op Utility
# Purpose|`Bond Buyer UOP30`|Development<br>Education<br>Electric Power<br>Environmental Facilities<br>General Purpose<br>Healthcare<br>Housing<br>Public Facilities<br>Transportation<br>Utilities
# Volume|`Amount of Maturity (M)`|Continuous
# County|`County`|Any county in the US
# State|`State`|Any state in the US
# Issue Date|`Sale Date`|Continuous (we only need the year)
#
# Fortunately, all of these variables appear in the common set.

# %%
#Define required variables
req_vars=['Security Type','Issuer Type Description','Bond Buyer UOP30',\
          'Amount of Maturity ($ mils)','County','State','Sale Date']
print 'All the requisite variables are in the common set:',np.array([var in common_vars for var in req_vars]).all()
# Out:
# All the requisite variables are in the common set: True

# %% [markdown]
# That makes things easier.  Let's just go ahead and read the data in from all years, keeping only the variables in `req_vars`.

# %%
#Create a container for DFs from all years
df_list=[]

#For each file...
for f in files:
    #...throw the subset into df_list
    df_list.append(pd.read_csv(f,usecols=req_vars))
    
#Concatenate all the years together
debt=pd.concat(df_list)

#Convert sale date to datetime
debt['Sale Date']=debt['Sale Date'].apply(lambda x: pd.to_datetime(x))

#Generate a year variable
debt['Year']=debt['Sale Date'].apply(lambda x: x.year)

#Jettison Sale Date
debt.pop('Sale Date')

print debt.info()
debt.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 465391 entries, 0 to 36385
# Data columns (total 7 columns):
# Bond Buyer UOP30               465388 non-null object
# Amount of Maturity ($ mils)    465391 non-null object
# County                         461215 non-null object
# Issuer Type Description        465357 non-null object
# State                          465365 non-null object
# Security Type                  465391 non-null object
# Year                           465391 non-null int64
# dtypes: int64(1), object(6)
# memory usage: 28.4+ MB
# None
#   Bond Buyer UOP30 Amount of Maturity ($ mils)           County  \
# 0        Utilities                        0.48         Callaway
# 1        Utilities                        0.05             Cass
# 2  General Purpose                       5.175         Gunnison
# 3        Education                       0.273  Clermont/Warren
# 4   Transportation                        0.22      Bartholomew
#
#   Issuer Type Description State Security Type  Year
# 0                District    MO            RV  1988
# 1          City, Town Vlg    MO            RV  1988
# 2                District    CO            GO  1988
# 3                District    OH            GO  1988
# 4                District    IN            GO  1988

# %% [markdown]
# We need to merge in FIPS codes, which are conveniently held by Census on a public site.

# %%
#Define names for fields
fips_names=['state','fips_st','fips_co','county','unknown']

#Capture dtypes of fips code variables (to keep the zeroes)
fips_dtypes={'fips_st':str,
             'fips_co':str}

#Read in fips
fips=pd.read_csv('http://www2.census.gov/geo/docs/reference/codes/files/national_county.txt',
                 names=fips_names,dtype=fips_dtypes)

#Remove 'County' and 'Parish' from the county names
fips['county']=fips['county'].str.replace(' County','')
fips['county']=fips['county'].str.replace(' Parish','')

#Create composite name and fips variables
fips['st_cou']=fips.apply(lambda row: row['state']+'_'+row['county'],axis=1)
fips['fips']=fips.apply(lambda row: row['fips_st']+row['fips_co'],axis=1)

#Capture dict to map composite names to composite fips codes
fips_dict=dict(zip(fips['st_cou'],fips['fips']))

#Generate composite name for the debt data
debt['st_cou']=debt.apply(lambda row: str(row['State'])+'_'+str(row['County']),axis=1)

#Map in fips codes
debt['FIPS']=debt['st_cou'].map(fips_dict)

debt
# Out:
#                Bond Buyer UOP30 Amount of Maturity ($ mils)  \
# 0                     Utilities                        0.48
# 1                     Utilities                        0.05
# 2               General Purpose                       5.175
# 3                     Education                       0.273
# 4                Transportation                        0.22
# 5                     Education                       1.798
# 6                    Healthcare                        0.09
# 7               General Purpose                        1.32
# 8               General Purpose                        3.68
# 9               General Purpose                       0.955
# 10                    Education                          12
# 11              General Purpose                       0.785
# 12              General Purpose                        0.09
# 13              General Purpose                       0.385
# 14              General Purpose                        0.41
# 15              General Purpose                         1.2
# 16                    Utilities                        0.38
# 17                   Healthcare                        2.02
# 18                    Utilities                      13.665
# 19                    Utilities                        7.28
# 20              General Purpose                           1
# 21               Transportation                         1.5
# 22              General Purpose                       0.125
# 23                    Education                           2
# 24               Transportation                         4.5
# 25              General Purpose                         6.2
# 26                    Education                         2.1
# 27              General Purpose                         2.5
# 28                    Education                       9.238
# 29                    Education                         2.9
# ...                         ...                         ...
# 36356               Development                       3.900
# 36357                 Education                       7.400
# 36358  Environmental Facilities                      18.650
# 36359                   Housing                       9.400
# 36360           General Purpose                     125.000
# 36361                   Housing                       5.800
# 36362                 Education                       0.230
# 36363           General Purpose                       1.625
# 36364           General Purpose                       0.200
# 36365                 Utilities                       0.130
# 36366           General Purpose                       1.450
# 36367                   Housing                       0.050
# 36368                 Education                       2.000
# 36369                 Education                       2.500
# 36370           General Purpose                       2.000
# 36371           General Purpose                       2.600
# 36372           General Purpose                       0.612
# 36373            Electric Power                       0.500
# 36374                 Education                       0.230
# 36375                Healthcare                       0.100
# 36376                Healthcare                      10.210
# 36377           General Purpose                       3.535
# 36378           General Purpose                       1.185
# 36379                Healthcare                       7.500
# 36380                 Utilities                      50.800
# 36381                   Housing                      13.500
# 36382                 Utilities                       6.500
# 36383                 Utilities                       6.625
# 36384           General Purpose                       1.442
# 36385           General Purpose                       2.600
#
#                                County Issuer Type Description State  \
# 0                            Callaway                District    MO
# 1                                Cass          City, Town Vlg    MO
# 2                            Gunnison                District    CO
# 3                     Clermont/Warren                District    OH
# 4                         Bartholomew                District    IN
# 5                                Lake                District    IN
# 6                              Carver          City, Town Vlg    MN
# 7                              Platte          City, Town Vlg    NE
# 8                              Grundy           County/Parish    IL
# 9                            St Croix          City, Town Vlg    WI
# 10                    State Authority         State Authority    MA
# 11                               Mesa           County/Parish    CO
# 12                             Benton          City, Town Vlg    IA
# 13                              Bowie          City, Town Vlg    TX
# 14                             Grundy          City, Town Vlg    IA
# 15                           Ben Hill           County/Parish    GA
# 16                               Pitt          City, Town Vlg    NC
# 17                             Mercer          City, Town Vlg    ND
# 18                    Campbell/Kenton                District    KY
# 19                             Denver          City, Town Vlg    CO
# 20                          Middlesex          City, Town Vlg    NJ
# 21                           Franklin          City, Town Vlg    OH
# 22                           Hamilton          City, Town Vlg    OH
# 23                             Monroe                District    NY
# 24                           Maricopa         Local Authority    AZ
# 25                            Alameda          City, Town Vlg    CA
# 26                             Porter                District    IN
# 27                          Middlesex          City, Town Vlg    NJ
# 28                          St Joseph                District    IN
# 29                         Washington                District    RI
# ...                               ...                     ...   ...
# 36356                 State Authority         State Authority    IL
# 36357        Lincoln/Minnehaha/Turner                District    SD
# 36358                 State Authority         State Authority    LA
# 36359              Nashville/Davidson         Local Authority    TN
# 36360                         Chester         Local Authority    PA
# 36361                 State Authority         State Authority    OR
# 36362                          Orange                District    IN
# 36363                       Jefferson          City, Town Vlg    WA
# 36364                           Posey          City, Town Vlg    IN
# 36365                          Fulton         Local Authority    AR
# 36366                           Sarpy                District    NE
# 36367                  Benton/Stearns          City, Town Vlg    MN
# 36368                           Tioga                District    NY
# 36369                           Tioga                District    NY
# 36370                      Tuscaloosa         Local Authority    AL
# 36371                      Tuscaloosa         Local Authority    AL
# 36372                        Cuyahoga          City, Town Vlg    OH
# 36373                             Sac          City, Town Vlg    IA
# 36374                      Washington                District    NY
# 36375                 State Authority         State Authority    WA
# 36376                 State Authority         State Authority    WA
# 36377                       Washtenaw           County/Parish    MI
# 36378                           Weber           County/Parish    UT
# 36379                 State Authority         State Authority    WI
# 36380  Tarrant/Denton/Parker/Johnson/          City, Town Vlg    TX
# 36381                        Franklin           County/Parish    OH
# 36382                  Grand Traverse           County/Parish    MI
# 36383                        Waukesha          City, Town Vlg    WI
# 36384                      Providence          City, Town Vlg    RI
# 36385                          Warren           County/Parish    IL
#
#       Security Type  Year                             st_cou   fips   FIPS
# 0                RV  1988                        MO_Callaway  29027  29027
# 1                RV  1988                            MO_Cass  29037  29037
# 2                GO  1988                        CO_Gunnison  08051  08051
# 3                GO  1988                 OH_Clermont/Warren    NaN    NaN
# 4                GO  1988                     IN_Bartholomew  18005  18005
# 5                GO  1988                            IN_Lake  18089  18089
# 6                RV  1988                          MN_Carver  27019  27019
# 7                GO  1988                          NE_Platte  31141  31141
# 8                GO  1988                          IL_Grundy  17063  17063
# 9                GO  1988                        WI_St Croix    NaN    NaN
# 10               RV  1988                 MA_State Authority    NaN    NaN
# 11               RV  1988                            CO_Mesa  08077  08077
# 12               GO  1988                          IA_Benton  19011  19011
# 13               GO  1988                           TX_Bowie  48037  48037
# 14               GO  1988                          IA_Grundy  19075  19075
# 15               GO  1988                        GA_Ben Hill  13017  13017
# 16               GO  1988                            NC_Pitt  37147  37147
# 17               RV  1988                          ND_Mercer  38057  38057
# 18               RV  1988                 KY_Campbell/Kenton    NaN    NaN
# 19               GO  1988                          CO_Denver  08031  08031
# 20               GO  1988                       NJ_Middlesex  34023  34023
# 21               GO  1988                        OH_Franklin  39049  39049
# 22               GO  1988                        OH_Hamilton  39061  39061
# 23               GO  1988                          NY_Monroe  36055  36055
# 24               RV  1988                        AZ_Maricopa  04013  04013
# 25               RV  1988                         CA_Alameda  06001  06001
# 26               GO  1988                          IN_Porter  18127  18127
# 27               GO  1988                       NJ_Middlesex  34023  34023
# 28               GO  1988                       IN_St Joseph    NaN    NaN
# 29               GO  1988                      RI_Washington  44009  44009
# ...             ...   ...                                ...    ...    ...
# 36356            RV  2003                 IL_State Authority    NaN    NaN
# 36357            GO  2003        SD_Lincoln/Minnehaha/Turner    NaN    NaN
# 36358            RV  2003                 LA_State Authority    NaN    NaN
# 36359            RV  2003              TN_Nashville/Davidson    NaN    NaN
# 36360            RV  2003                         PA_Chester  42029  42029
# 36361            RV  2003                 OR_State Authority    NaN    NaN
# 36362            GO  2003                          IN_Orange  18117  18117
# 36363            GO  2003                       WA_Jefferson  53031  53031
# 36364            GO  2003                           IN_Posey  18129  18129
# 36365            RV  2003                          AR_Fulton  05049  05049
# 36366            GO  2003                           NE_Sarpy  31153  31153
# 36367            RV  2003                  MN_Benton/Stearns    NaN    NaN
# 36368            GO  2003                           NY_Tioga  36107  36107
# 36369            GO  2003                           NY_Tioga  36107  36107
# 36370            RV  2003                      AL_Tuscaloosa  01125  01125
# 36371            RV  2003                      AL_Tuscaloosa  01125  01125
# 36372            GO  2003                        OH_Cuyahoga  39035  39035
# 36373            RV  2003                             IA_Sac  19161  19161
# 36374            GO  2003                      NY_Washington  36115  36115
# 36375            RV  2003                 WA_State Authority    NaN    NaN
# 36376            RV  2003                 WA_State Authority    NaN    NaN
# 36377            GO  2003                       MI_Washtenaw  26161  26161
# 36378            RV  2003                           UT_Weber  49057  49057
# 36379            RV  2003                 WI_State Authority    NaN    NaN
# 36380            RV  2003  TX_Tarrant/Denton/Parker/Johnson/    NaN    NaN
# 36381            RV  2003                        OH_Franklin  39049  39049
# 36382            GO  2003                  MI_Grand Traverse  26055  26055
# 36383            RV  2003                        WI_Waukesha  55133  55133
# 36384            RV  2003                      RI_Providence  44007  44007
# 36385            RV  2003                          IL_Warren  17187  17187
#
# [465391 rows x 10 columns]

# %% [markdown]
# Ok, that got about three quarters of the records.  Let's try to get the rest.  Many issuers come from the `State Authority` or the `State` outright.  Pretty much, if `State` is anywhere in the description, no single county can be affiliated with the issue. So, let's allocate the state FIPS to all of them.

# %%
#Capture states
states=sorted(set(debt['State']))[1:]

#For each state...
for st in states:
    #...capture the keys associated with that state...
    st_keys=[item for item in fips_dict.items() if str(st)+'_' in item[0]]
    try:
        #...extract the state portion of the value associated with the first member of the list...
        st_key_part=st_keys[0][1][:2]
        #...and assign the state fips code
        debt.ix[(debt['State']==st) & ('State' in debt['Issuer Type Description']),'FIPS']=st_key_part+'000'
#         debt.ix[(debt['State']==st) & (debt['County']=='State'),'FIPS']=st_key_part+'000'
    except:
        print 'Problem state >>> ',st

debt[debt['County']=='State Authority']
# Out:
# Problem state >>>  MR
# Problem state >>>  TT
#        State Bond Buyer UOP30 Amount of Maturity ($ mils)           County  \
# 0         AK          Housing                          43  State Authority
# 2         AK          Housing                        9.86  State Authority
# 6         AK          Housing                      43.385  State Authority
# 7         AK        Education                      58.850  State Authority
# 12        AK      Development                       1.175  State Authority
# 13        AK      Development                        1.81  State Authority
# 14        AK          Housing                          21  State Authority
# 16        AK          Housing                       38.25  State Authority
# 18        AK          Housing                       24.72  State Authority
# 19        AK        Education                           5  State Authority
# 21        AK      Development                        2.19  State Authority
# 25        AK          Housing                       72.75  State Authority
# 27        AK        Education                       31.16  State Authority
# 30        AK          Housing                         9.6  State Authority
# 32        AK      Development                       2.815  State Authority
# 33        AK      Development                       2.815  State Authority
# 38        AK   Electric Power                      29.735  State Authority
# 39        AK          Housing                          75  State Authority
# 41        AK   Transportation                          12  State Authority
# 43        AK          Housing                          70  State Authority
# 44        AK          Housing                       5.425  State Authority
# 45        AK          Housing                          75  State Authority
# 47        AK          Housing                         148  State Authority
# 54        AK          Housing                      11.315  State Authority
# 55        AK          Housing                      42.125  State Authority
# 56        AK          Housing                      19.955  State Authority
# 57        AK        Education                       5.230  State Authority
# 60        AK        Education                      19.570  State Authority
# 61        AK        Education                      45.500  State Authority
# 76        AK       Healthcare                      60.000  State Authority
# ...      ...              ...                         ...              ...
# 465206    WY        Education                          20  State Authority
# 465212    WY          Housing                      10.435  State Authority
# 465213    WY          Housing                       9.215  State Authority
# 465222    WY          Housing                      50.000  State Authority
# 465237    WY        Education                          20  State Authority
# 465238    WY          Housing                      15.765  State Authority
# 465239    WY          Housing                      26.655  State Authority
# 465259    WY   Electric Power                        3.18  State Authority
# 465260    WY          Housing                      20.316  State Authority
# 465282    WY      Development                        23.6  State Authority
# 465293    WY          Housing                      53.690  State Authority
# 465304    WY          Housing                       5.225  State Authority
# 465305    WY          Housing                       0.755  State Authority
# 465306    WY          Housing                        6.59  State Authority
# 465312    WY        Education                      50.000  State Authority
# 465323    WY          Housing                       7.400  State Authority
# 465324    WY          Housing                      37.000  State Authority
# 465328    WY  General Purpose                      10.405  State Authority
# 465329    WY        Education                      20.000  State Authority
# 465334    WY          Housing                       5.000  State Authority
# 465335    WY          Housing                       1.500  State Authority
# 465336    WY          Housing                       4.600  State Authority
# 465347    WY          Housing                       6.000  State Authority
# 465348    WY          Housing                      15.715  State Authority
# 465353    WY          Housing                       6.000  State Authority
# 465357    WY          Housing                       2.405  State Authority
# 465358    WY          Housing                       5.000  State Authority
# 465359    WY          Housing                       5.220  State Authority
# 465363    WY          Housing                       2.820  State Authority
# 465364    WY          Housing                       2.955  State Authority
#
#        Issuer Type Description Security Type  Year              st_cou fips  \
# 0              State Authority            RV  1988  AK_State Authority  NaN
# 2              State Authority            RV  1988  AK_State Authority  NaN
# 6              State Authority            RV  1988  AK_State Authority  NaN
# 7              State Authority            RV  1988  AK_State Authority  NaN
# 12             State Authority            RV  1988  AK_State Authority  NaN
# 13             State Authority            GO  1988  AK_State Authority  NaN
# 14             State Authority            RV  1988  AK_State Authority  NaN
# 16             State Authority            RV  1988  AK_State Authority  NaN
# 18             State Authority            RV  1988  AK_State Authority  NaN
# 19             State Authority            RV  1988  AK_State Authority  NaN
# 21             State Authority            RV  1988  AK_State Authority  NaN
# 25             State Authority            RV  1989  AK_State Authority  NaN
# 27             State Authority            RV  1989  AK_State Authority  NaN
# 30             State Authority            RV  1989  AK_State Authority  NaN
# 32             State Authority            RV  1989  AK_State Authority  NaN
# 33             State Authority            RV  1989  AK_State Authority  NaN
# 38             State Authority            RV  1989  AK_State Authority  NaN
# 39             State Authority            RV  1989  AK_State Authority  NaN
# 41             State Authority            RV  1989  AK_State Authority  NaN
# 43             State Authority            RV  1989  AK_State Authority  NaN
# 44             State Authority            RV  1989  AK_State Authority  NaN
# 45             State Authority            RV  1989  AK_State Authority  NaN
# 47             State Authority            RV  1989  AK_State Authority  NaN
# 54             State Authority            RV  2004  AK_State Authority  NaN
# 55             State Authority            RV  2004  AK_State Authority  NaN
# 56             State Authority            RV  2004  AK_State Authority  NaN
# 57             State Authority            RV  2004  AK_State Authority  NaN
# 60             State Authority            RV  2004  AK_State Authority  NaN
# 61             State Authority            RV  2004  AK_State Authority  NaN
# 76             State Authority            RV  2004  AK_State Authority  NaN
# ...                        ...           ...   ...                 ...  ...
# 465206         State Authority            RV  1997  WY_State Authority  NaN
# 465212         State Authority            RV  1997  WY_State Authority  NaN
# 465213         State Authority            RV  1997  WY_State Authority  NaN
# 465222         State Authority            RV  1997  WY_State Authority  NaN
# 465237         State Authority            RV  1997  WY_State Authority  NaN
# 465238         State Authority            RV  1997  WY_State Authority  NaN
# 465239         State Authority            RV  1997  WY_State Authority  NaN
# 465259         State Authority            RV  1984  WY_State Authority  NaN
# 465260         State Authority            RV  1984  WY_State Authority  NaN
# 465282         State Authority            RV  1984  WY_State Authority  NaN
# 465293         State Authority            RV  1985  WY_State Authority  NaN
# 465304         State Authority            RV  2002  WY_State Authority  NaN
# 465305         State Authority            RV  2002  WY_State Authority  NaN
# 465306         State Authority            RV  2002  WY_State Authority  NaN
# 465312         State Authority            RV  2002  WY_State Authority  NaN
# 465323         State Authority            RV  2002  WY_State Authority  NaN
# 465324         State Authority            RV  2002  WY_State Authority  NaN
# 465328         State Authority            RV  2002  WY_State Authority  NaN
# 465329         State Authority            RV  2002  WY_State Authority  NaN
# 465334         State Authority            RV  2002  WY_State Authority  NaN
# 465335         State Authority            RV  2002  WY_State Authority  NaN
# 465336         State Authority            RV  2002  WY_State Authority  NaN
# 465347         State Authority            RV  2003  WY_State Authority  NaN
# 465348         State Authority            RV  2003  WY_State Authority  NaN
# 465353         State Authority            RV  2003  WY_State Authority  NaN
# 465357         State Authority            RV  2003  WY_State Authority  NaN
# 465358         State Authority            RV  2003  WY_State Authority  NaN
# 465359         State Authority            RV  2003  WY_State Authority  NaN
# 465363         State Authority            RV  2003  WY_State Authority  NaN
# 465364         State Authority            RV  2003  WY_State Authority  NaN
#
#          FIPS
# 0       02000
# 2       02000
# 6       02000
# 7       02000
# 12      02000
# 13      02000
# 14      02000
# 16      02000
# 18      02000
# 19      02000
# 21      02000
# 25      02000
# 27      02000
# 30      02000
# 32      02000
# 33      02000
# 38      02000
# 39      02000
# 41      02000
# 43      02000
# 44      02000
# 45      02000
# 47      02000
# 54      02000
# 55      02000
# 56      02000
# 57      02000
# 60      02000
# 61      02000
# 76      02000
# ...       ...
# 465206  56000
# 465212  56000
# 465213  56000
# 465222  56000
# 465237  56000
# 465238  56000
# 465239  56000
# 465259  56000
# 465260  56000
# 465282  56000
# 465293  56000
# 465304  56000
# 465305  56000
# 465306  56000
# 465312  56000
# 465323  56000
# 465324  56000
# 465328  56000
# 465329  56000
# 465334  56000
# 465335  56000
# 465336  56000
# 465347  56000
# 465348  56000
# 465353  56000
# 465357  56000
# 465358  56000
# 465359  56000
# 465363  56000
# 465364  56000
#
# [41979 rows x 10 columns]

# %%
debt.ix[(debt['FIPS'].isnull()) & (debt['State']=='AK')]
# Out:
#     State          Bond Buyer UOP30 Amount of Maturity ($ mils)  \
# 1      AK                 Utilities                       7.815
# 3      AK           General Purpose                      27.813
# 4      AK           General Purpose                       16.06
# 5      AK                 Education                      23.000
# 8      AK           General Purpose                      14.500
# 9      AK         Public Facilities                       2.000
# 10     AK           General Purpose                          86
# 11     AK           General Purpose                          25
# 15     AK           General Purpose                       3.145
# 17     AK                 Utilities                           5
# 20     AK                 Education                       21.83
# 22     AK           General Purpose                       0.738
# 23     AK           General Purpose                       0.458
# 24     AK         Public Facilities                         1.4
# 26     AK           General Purpose                        2.71
# 28     AK           General Purpose                        1.88
# 29     AK                 Utilities                       0.805
# 31     AK                 Education                        0.69
# 34     AK           General Purpose                      10.360
# 35     AK  Environmental Facilities                       2.410
# 36     AK  Environmental Facilities                       2.410
# 37     AK            Electric Power                      41.050
# 40     AK                 Utilities                        5.32
# 42     AK                 Education                          60
# 46     AK                 Education                          12
# 48     AK           General Purpose                       8.500
# 49     AK                 Utilities                       7.355
# 50     AK           General Purpose                       1.970
# 51     AK                 Utilities                      33.255
# 52     AK           General Purpose                      20.270
# ..    ...                       ...                         ...
# 829    AK                 Education                      23.855
# 833    AK           General Purpose                      11.695
# 835    AK           General Purpose                      24.468
# 836    AK                   Housing                       6.000
# 840    AK                 Education                       1.420
# 841    AK                 Utilities                       6.250
# 842    AK                 Education                      14.000
# 843    AK           General Purpose                       9.305
# 844    AK            Transportation                       5.685
# 845    AK           General Purpose                       3.075
# 846    AK           General Purpose                      13.500
# 849    AK            Transportation                      93.500
# 850    AK                Healthcare                      12.860
# 851    AK           General Purpose                       8.250
# 853    AK           General Purpose                      25.000
# 855    AK           General Purpose                       1.035
# 856    AK           General Purpose                      12.695
# 858    AK            Transportation                     375.000
# 859    AK           General Purpose                      35.000
# 860    AK                 Education                     126.770
# 862    AK           General Purpose                      21.260
# 863    AK           General Purpose                       3.320
# 864    AK           General Purpose                      13.250
# 865    AK           General Purpose                      20.000
# 866    AK            Transportation                     128.230
# 867    AK           General Purpose                       3.500
# 870    AK                 Education                       7.265
# 873    AK                Healthcare                      47.985
# 874    AK           General Purpose                      24.110
# 875    AK                 Education                       9.335
#
#                   County Issuer Type Description Security Type  Year  \
# 1      Fairbanks No Star          City, Town Vlg            RV  1988
# 3      Fairbanks No Star          City, Town Vlg            GO  1988
# 4      Fairbanks No Star          City, Town Vlg            GO  1988
# 5              Anchorage          City, Town Vlg            GO  1988
# 8              Anchorage          City, Town Vlg            GO  1988
# 9      Matanuska-Susitna          City, Town Vlg            RV  1988
# 10           North Slope          City, Town Vlg            GO  1988
# 11           North Slope          City, Town Vlg            GO  1988
# 15                Juneau         State Authority            RV  1988
# 17     Fairbanks No Star          City, Town Vlg            RV  1988
# 20     Matanuska-Susitna          City, Town Vlg            GO  1988
# 22             Anchorage          City, Town Vlg            RV  1989
# 23   Wrangell-Petersburg          City, Town Vlg            GO  1989
# 24                Juneau          City, Town Vlg            GO  1989
# 26                Juneau         State Authority            GO  1989
# 28                 Sitka          City, Town Vlg            GO  1989
# 29                Juneau         State Authority            RV  1989
# 31         Kodiak Island          City, Town Vlg            GO  1989
# 34                Juneau         State Authority            GO  1989
# 35             Anchorage          City, Town Vlg            RV  1989
# 36             Anchorage          City, Town Vlg            RV  1989
# 37             Anchorage          City, Town Vlg            RV  1989
# 40             Anchorage          City, Town Vlg            GO  1989
# 42           North Slope          City, Town Vlg            GO  1989
# 46     Ketchikan Gateway          City, Town Vlg            GO  1989
# 48                Juneau          City, Town Vlg            GO  1989
# 49             Anchorage          City, Town Vlg            RV  1989
# 50                Juneau         State Authority            GO  1989
# 51     Fairbanks No Star          City, Town Vlg            RV  1989
# 52                Juneau         State Authority            GO  2004
# ..                   ...                     ...           ...   ...
# 829            Fairbanks         College or Univ            RV  2002
# 833               Juneau         State Authority            GO  2002
# 835          North Slope          City, Town Vlg            GO  2002
# 836                  NaN            Indian Tribe            RV  2002
# 840               Juneau          City, Town Vlg            GO  2002
# 841               Juneau         State Authority            RV  2002
# 842    Fairbanks No Star          City, Town Vlg            GO  2002
# 843               Juneau         State Authority            GO  2003
# 844               Juneau         State Authority            RV  2003
# 845               Juneau         State Authority            GO  2003
# 846    Fairbanks No Star          City, Town Vlg            GO  2003
# 849       Valdez/Cordova          City, Town Vlg            RV  2003
# 850               Juneau         State Authority            RV  2003
# 851               Juneau         State Authority            GO  2003
# 853            Anchorage          City, Town Vlg            GO  2003
# 855               Juneau         State Authority            RV  2003
# 856               Juneau         State Authority            GO  2003
# 858       Valdez/Cordova          City, Town Vlg            RV  2003
# 859            Anchorage          City, Town Vlg            GO  2003
# 860            Anchorage          City, Town Vlg            GO  2003
# 862               Juneau         State Authority            GO  2003
# 863               Juneau         State Authority            GO  2003
# 864               Juneau          City, Town Vlg            GO  2003
# 865               Juneau          City, Town Vlg            GO  2003
# 866       Valdez/Cordova          City, Town Vlg            RV  2003
# 867          North Slope          City, Town Vlg            GO  2003
# 870            Fairbanks         College or Univ            RV  2003
# 873      Kenai Peninsula          City, Town Vlg            GO  2003
# 874               Juneau         State Authority            GO  2003
# 875            Fairbanks         College or Univ            RV  2003
#
#                      st_cou fips FIPS
# 1      AK_Fairbanks No Star  NaN  NaN
# 3      AK_Fairbanks No Star  NaN  NaN
# 4      AK_Fairbanks No Star  NaN  NaN
# 5              AK_Anchorage  NaN  NaN
# 8              AK_Anchorage  NaN  NaN
# 9      AK_Matanuska-Susitna  NaN  NaN
# 10           AK_North Slope  NaN  NaN
# 11           AK_North Slope  NaN  NaN
# 15                AK_Juneau  NaN  NaN
# 17     AK_Fairbanks No Star  NaN  NaN
# 20     AK_Matanuska-Susitna  NaN  NaN
# 22             AK_Anchorage  NaN  NaN
# 23   AK_Wrangell-Petersburg  NaN  NaN
# 24                AK_Juneau  NaN  NaN
# 26                AK_Juneau  NaN  NaN
# 28                 AK_Sitka  NaN  NaN
# 29                AK_Juneau  NaN  NaN
# 31         AK_Kodiak Island  NaN  NaN
# 34                AK_Juneau  NaN  NaN
# 35             AK_Anchorage  NaN  NaN
# 36             AK_Anchorage  NaN  NaN
# 37             AK_Anchorage  NaN  NaN
# 40             AK_Anchorage  NaN  NaN
# 42           AK_North Slope  NaN  NaN
# 46     AK_Ketchikan Gateway  NaN  NaN
# 48                AK_Juneau  NaN  NaN
# 49             AK_Anchorage  NaN  NaN
# 50                AK_Juneau  NaN  NaN
# 51     AK_Fairbanks No Star  NaN  NaN
# 52                AK_Juneau  NaN  NaN
# ..                      ...  ...  ...
# 829            AK_Fairbanks  NaN  NaN
# 833               AK_Juneau  NaN  NaN
# 835          AK_North Slope  NaN  NaN
# 836                  AK_nan  NaN  NaN
# 840               AK_Juneau  NaN  NaN
# 841               AK_Juneau  NaN  NaN
# 842    AK_Fairbanks No Star  NaN  NaN
# 843               AK_Juneau  NaN  NaN
# 844               AK_Juneau  NaN  NaN
# 845               AK_Juneau  NaN  NaN
# 846    AK_Fairbanks No Star  NaN  NaN
# 849       AK_Valdez/Cordova  NaN  NaN
# 850               AK_Juneau  NaN  NaN
# 851               AK_Juneau  NaN  NaN
# 853            AK_Anchorage  NaN  NaN
# 855               AK_Juneau  NaN  NaN
# 856               AK_Juneau  NaN  NaN
# 858       AK_Valdez/Cordova  NaN  NaN
# 859            AK_Anchorage  NaN  NaN
# 860            AK_Anchorage  NaN  NaN
# 862               AK_Juneau  NaN  NaN
# 863               AK_Juneau  NaN  NaN
# 864               AK_Juneau  NaN  NaN
# 865               AK_Juneau  NaN  NaN
# 866       AK_Valdez/Cordova  NaN  NaN
# 867          AK_North Slope  NaN  NaN
# 870            AK_Fairbanks  NaN  NaN
# 873      AK_Kenai Peninsula  NaN  NaN
# 874               AK_Juneau  NaN  NaN
# 875            AK_Fairbanks  NaN  NaN
#
# [544 rows x 10 columns]

# %%
debt.ix[(debt['FIPS'].isnull()) & ('State' in debt['Issuer Type Description'])]

# %%
print debt.ix[(debt['FIPS'].isnull())].ix[26]
'State' in debt.ix[(debt['FIPS'].isnull())].ix[26]['Issuer Type Description']
# Out:
# State                                       AK
# Bond Buyer UOP30               General Purpose
# Amount of Maturity ($ mils)               2.71
# County                                  Juneau
# Issuer Type Description        State Authority
# Security Type                               GO
# Year                                      1989
# st_cou                               AK_Juneau
# fips                                       NaN
# FIPS                                       NaN
# Name: 26, dtype: object
# True

# %%
states
# Out:
# ['AK',
#  'AL',
#  'AR',
#  'AS',
#  'AZ',
#  'CA',
#  'CO',
#  'CT',
#  'DC',
#  'DE',
#  'FL',
#  'GA',
#  'GU',
#  'HI',
#  'IA',
#  'ID',
#  'IL',
#  'IN',
#  'KS',
#  'KY',
#  'LA',
#  'MA',
#  'MD',
#  'ME',
#  'MI',
#  'MN',
#  'MO',
#  'MR',
#  'MS',
#  'MT',
#  'N',
#  'NC',
#  'ND',
#  'NE',
#  'NH',
#  'NJ',
#  'NM',
#  'NV',
#  'NY',
#  'OH',
#  'OK',
#  'OR',
#  'PA',
#  'PR',
#  'RI',
#  'SC',
#  'SD',
#  'TN',
#  'TT',
#  'TX',
#  'UT',
#  'VA',
#  'VI',
#  'VT',
#  'WA',
#  'WI',
#  'WV',
#  'WY']
