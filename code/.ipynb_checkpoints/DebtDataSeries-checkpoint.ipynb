# %% [markdown]
# # Debt Data Time Series

# %% [markdown]
# This script seeks to grab the subset of relevant variables from each year, so that we have a set across all years that can be readily merged with the TEL/ACS data.

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import glob
import requests

# %% [markdown]
# ## What are the common variables?

# %% [markdown]
# The first thing we will do is see if we can get what we need from just the common variables across all sets.  There are a few reasons why variables may not align every year:
#
# 1. Reuters doesn't offer the entire set of variables every year;
# 2. Variable names with long words may have been hyphenated in different ways across years;
# 3. If variables appeared more than once, the parsing routine appended the variable position to the name to create a unique variable.  If the position varies across years, so will the variable name.
#
# To grab the columns in lightweight fashion, we will just read in the first couple lines for each set.

# %%
#Grab list of files
files=glob.glob('../../debt_data/*.csv')

#Create a dictionary to hold columns from each year
col_dict={}

#For each file...
for f in files:
    #...read in the first couple rows...
    tmp_df=pd.read_csv(f,nrows=2)
    #...capture the columns...
    col_dict.update({f[13:-4]:list(tmp_df.columns)})
    #...and dump the partial data set
    del tmp_df
    
#Create a container for the variable sets within each file
var_sets=[]

#For each file...
for f in col_dict.keys():
    #...add the variable set to var_sets
    var_sets.append(set(col_dict[f]))
    
#Capture the intersection of variables across all years
common_vars=sorted(list(set.intersection(*var_sets)))

print 'There are '+str(len(common_vars))+' variables common to all sets.'
print common_vars
# Out:
# There are 254 variables common to all sets.
# ['# of Mgrs', '$ Amount of Highest Cpn Maturity', '144A FLAG', '501c3', '8-Digit CUSIP25', '8-Digit CUSIP26', 'Accumulator Amt ($ Mil)', 'All Use of Proceeds (Code)', 'All Use of Proceeds (Desc)', 'All Use of Proceeds (Number)', 'Amount at Maturity ($ mils)', 'Amount of Final Maturity ($mils)', 'Amount of Issue ($ mils)', 'Amount of Maturity ($ mils)', 'Ant- ici- pa- tion Type', 'Asset Backed Indicator Flag (Y/N)', 'Auction Rate', 'Aver- age Life', 'Average Take Down', 'Bank Qual', 'Beginning Price/ Yield', 'Beginning Serial Coupon', 'Beginning Serial Maturity', 'Bid', 'Bk Elig', 'Bk En- try', 'Bnk Mgd', 'Bond Buyer ALL UOP', 'Bond Buyer GO Index', 'Bond Buyer Region118', 'Bond Buyer Region119', 'Bond Buyer Rev. Index', 'Bond Buyer UOP142', 'Bond Buyer UOP143', 'Bond Buyer UOP30', 'Bond Counsel Deal(Y/N)', 'CD-ROM Number', 'CUSIP of Insti- tutional Backer', 'Call Date', 'Call Issue', 'Call Price', 'Callable at Par', 'Co-Managers', 'Comb. Gross Spread', 'Comm- ercial Paper', 'Comp Amount of Issue ($ mils)', 'Conversion Date (Maty)', 'Corp orate Backed', 'Corporate or Institutional Backer', 'County', 'Coupon Maturity', 'Coupon Rate', 'Coupon Type67', 'Coupon Type69', 'Coupon Type70', 'Coupon of Fin Maty', 'Coupon of Maturity', 'Cpn Type', 'Credit Enhance ment Type71', 'Credit Enhance ment Type72', 'Credit Enhancer73', 'Credit Enhancer74', 'Credit Enhancer75', 'Cusip', 'DALCOMP Number', 'DOUBLE BARRELED', 'DTC Elig', 'Date Issue Added', 'Dated Date17', 'Dated Date18', 'Days to Delivery Calculator', 'Dealno of Refunded Issue', 'Deals with Profors/Obligors (Y/N)', 'Delivery Date', 'Denomination', 'Deriv- ative Type', 'Disclosure Counsel', 'Disclosure Counsel Deal(Y/N)', 'Edtype', 'Electronic Bidding System', 'Electronic Bidding Y/N Flag', 'Email Address', 'Ending Price/ Yield', 'Ending Serial Coupon', 'Ending Serial Maturity', 'Ending Serial Price/ Yield', 'Expenses', 'Extra ord. Redem', 'FITCH Rating', 'Fiche #', 'Final Mat. Year', 'Final Maturity', 'Financial Advisor Deal(Y/N)', 'Financial Advisor106', 'Financial Advisor107', 'Financial Advisor108', 'First Call Date', 'First Interest Payment Date', 'First Sinking Fund Date', 'Fitch Underlying Rating', 'Fitch Underlying Short Rating', 'Fitch109', 'Fitch110', 'Fitch112', 'Fitch113', 'General Use of Proceeds', 'Genl Use of Procd', 'Gross Spread', 'Highest Coupon', 'Hosp- ital Code', 'Hospital Code', 'Industry', 'Initial Call Price', 'Initial Put Date', 'Insured Amount', 'Issue Dated Date', 'Issue Description', 'Issue Number', 'Issuer', 'Issuer Cusips', 'Issuer Type', 'Issuer Type Description', 'Issuer Website', "Issuer's Counsel134", "Issuer's Counsel135", "Issuer's Counsel136", 'Joint Action Issuer', 'Lead Manager', 'Lease Type', 'Letter of Credit Expiration Date (Maty)', 'Main Use of Proceeds', 'Main Use of Proceeds (Code)', 'Main Use of Proceeds (Number)', 'Manager Allocation Amount (US$ Mil)', 'Managers219', 'Managers28', 'Marketplace', 'Marketplace Code', 'Master Deal Type', 'Maturity Amount', 'Maturity Date5', 'Maturity Date7', 'Maturity Year', 'Maturity16', 'Maturity6', 'Maty of Highest Cpn Maty', 'Mgmnt Fee', 'Minority Firm as Bond Counsel Flag (Y/N)', 'Minority Firm as Co-Mgr', 'Minority Manager', 'Mlt Sys Hsp', 'Moody Rating156', 'Moody Rating159', 'Moody S&P plit Rated', 'Moody Short Rating', "Moody's Long Term Rating", "Moody's Underlying Long Term Rating", 'Mtg Loan Rate', 'Nation Code', 'Nation169', 'Nation170', 'Net Proceeds', 'Net nterest Cost', 'Notes (1)', 'Notes (2)', 'Notes (3)', 'Number', 'Number of Co-Lead Managers', 'OS tatus', 'Off- Type', 'Other Interest Cost', 'Other Interest Cost Type', 'PENSION FLAG', 'Par Amount per Book Runner', 'Paying Agent (Y/N)', 'Paying Agent182', 'Paying Agent183', 'Paying Agent184', 'Phone Number', 'Pooled Issue', 'Pre-Ref Date', 'Pre-Ref Status', 'Preliminary Issue Flag', 'Price/ Yield of Maturity', 'Principal Amount', 'Project191', 'Project192', 'Prov. or Cond. Rating', 'Put Freq', 'Qualified Zone Academy Bonds (Y/N) Flag', 'Ra ...

# %% [markdown]
# ## Data Input

# %% [markdown]
# Ok, we are looking for aggregations of debt by county.  In particular, we want to capture activity by concepts:
#
# 1. Type of Debt (General Obligation or Revenue; latter can be split by )
# 2. Issuer Type (General purpose gov, school district, special district, or private entity)
# 3. Purpose of the Issue
# 4. Volume of Issue
#
# For the latter two, we also want variables that split out GO versus revenue bonds.  For example, we would want to know the volume of GO debt issued by general purpose jurisdictions, or the revenue debt issued in service of transportation infrastructure.  The following table maps concepts to variables.
#
# Concept|Variable|Possible Values
# -------|--------|---------------
# Debt Type|`Security Type`| GO<br>RV
# Issuer Type|`Issuer Type Description`|District<br>City, Town Vlg<br>Local Authority<br>State Authority<br>County/Parish<br>College or Univ<br>State/Province<br>Direct<br>Indian Tribe<br>Co-op Utility
# Purpose|`Bond Buyer UOP30`|Development<br>Education<br>Electric Power<br>Environmental Facilities<br>General Purpose<br>Healthcare<br>Housing<br>Public Facilities<br>Transportation<br>Utilities
# Volume|`Amount of Maturity (M)`|Continuous
# County|`County`|Any county in the US
# State|`State`|Any state in the US
# Issue Date|`Sale Date`|Continuous (we only need the year)
#
# Fortunately, all of these variables appear in the common set.

# %%
#Define required variables
req_vars=['Security Type','Issuer Type Description','Bond Buyer UOP30',\
          'Amount of Maturity ($ mils)','County','State','Sale Date','Issuer']
print 'All the requisite variables are in the common set:',np.array([var in common_vars for var in req_vars]).all()
# Out:
# All the requisite variables are in the common set: True

# %% [markdown]
# That makes things easier.  Let's just go ahead and read the data in from all years, keeping only the variables in `req_vars`.

# %%
#Create a container for DFs from all years
df_list=[]

#For each file...
for f in files:
    #...throw the subset into df_list
    df_list.append(pd.read_csv(f,usecols=req_vars))
    
#Concatenate all the years together
debt=pd.concat(df_list)

#Convert sale date to datetime
debt['Sale Date']=debt['Sale Date'].apply(lambda x: pd.to_datetime(x))

#Generate a year variable
debt['Year']=debt['Sale Date'].apply(lambda x: x.year)

#Jettison Sale Date
debt.pop('Sale Date')

print debt.info()
debt.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 465391 entries, 0 to 34710
# Data columns (total 8 columns):
# Bond Buyer UOP30               465388 non-null object
# Amount of Maturity ($ mils)    465391 non-null object
# County                         461215 non-null object
# Issuer                         465357 non-null object
# Issuer Type Description        465357 non-null object
# State                          465365 non-null object
# Security Type                  465391 non-null object
# Year                           465391 non-null int64
# dtypes: int64(1), object(7)
# memory usage: 32.0+ MB
# None
# /home/choct155/analysis/Anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2902: DtypeWarning: Columns (39) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Bond Buyer UOP30 Amount of Maturity ($ mils)     County  \
# 0  General Purpose                       0.076      Salem
# 1   Transportation                       0.280       Holt
# 2      Development                       5.915   Beltrami
# 3        Education                       1.983     Broome
# 4  General Purpose                       5.666  Middlesex
#
#                            Issuer Issuer Type Description State Security Type  \
# 0          Alloway Twp-New Jersey          City, Town Vlg    NJ            GO
# 1          Atkinson City-Nebraska          City, Town Vlg    NE            GO
# 2  Bemidji Economic Dev Authority         Local Authority    MN            GO
# 3         Broome Co (Johnson) CSD                District    NY            GO
# 4         Cranbury Twp-New Jersey          City, Town Vlg    NJ            GO
#
#    Year
# 0  2012
# 1  2012
# 2  2012
# 3  2012
# 4  2012

# %% [markdown]
# ## Identification of FIPS codes

# %% [markdown]
# We need to merge in FIPS codes, which are conveniently held by Census on a public site.

# %%
#Define names for fields
fips_names=['state','fips_st','fips_co','county','unknown']

#Capture dtypes of fips code variables (to keep the zeroes)
fips_dtypes={'fips_st':str,
             'fips_co':str}

#Read in fips
fips=pd.read_csv('http://www2.census.gov/geo/docs/reference/codes/files/national_county.txt',
                 names=fips_names,dtype=fips_dtypes)

#Remove 'County' and 'Parish' from the county names
fips['county']=fips['county'].str.replace(' County','')
fips['county']=fips['county'].str.replace(' Parish','')

#Create composite name and fips variables
fips['st_cou']=fips.apply(lambda row: (row['state']+'_'+row['county']).lower(),axis=1)
fips['fips']=fips.apply(lambda row: (row['fips_st']+row['fips_co']).lower(),axis=1)

#Capture dict to map composite names to composite fips codes
fips_dict=dict(zip(fips['st_cou'],fips['fips']))

#Fix the counties with 'St' (insert a period)
debt['County']=debt['County'].str.replace('St ','St. ')

#Generate composite name for the debt data
debt['st_cou']=debt.apply(lambda row: (str(row['State'])+'_'+str(row['County'])).lower(),axis=1)

#Map in fips codes
debt['FIPS']=debt['st_cou'].map(fips_dict)

#Write in temporary set (before FIPS improvement)
debt.to_csv('debt_ts_pre_fips.csv')

debt
# Out:
#         Bond Buyer UOP30 Amount of Maturity ($ mils)                  County  \
# 0        General Purpose                       0.076                   Salem
# 1         Transportation                       0.280                    Holt
# 2            Development                       5.915                Beltrami
# 3              Education                       1.983                  Broome
# 4        General Purpose                       5.666               Middlesex
# 5              Utilities                       1.361                  Solano
# 6        General Purpose                       1.365               Marinette
# 7        General Purpose                       5.000                  Putnam
# 8              Education                      31.770             Bartholomew
# 9        General Purpose                      38.330                  Orange
# 10       General Purpose                       0.224                Onondaga
# 11             Utilities                       0.211               Worcester
# 12             Education                       0.175                Cleburne
# 13             Education                       1.145  Clinton/Essex/Franklin
# 14             Education                       7.825              New London
# 15             Education                      14.500              New London
# 16       General Purpose                       0.844             Westchester
# 17             Education                       0.970                     Elk
# 18             Education                       0.090                 Elliott
# 19       General Purpose                       2.435                   Cooke
# 20       General Purpose                       4.500                  Nassau
# 21             Utilities                       8.710                Franklin
# 22             Education                       8.010                 Hancock
# 23       General Purpose                       5.500                    York
# 24       General Purpose                       1.500                    Knox
# 25       General Purpose                       1.000              Montgomery
# 26             Education                       2.745                  Marion
# 27             Utilities                       1.800                   Union
# 28       General Purpose                       0.357                  Nassau
# 29             Education                       0.920                  Monroe
# ...                  ...                         ...                     ...
# 34681            Housing                        0.23           Bossier/Caddo
# 34682    General Purpose                       0.801                   Union
# 34683        Development                         1.7                  Beaver
# 34684    General Purpose                       10.72              Providence
# 34685        Development                         2.5               Albemarle
# 34686    General Purpose                       0.237                  Monroe
# 34687     Electric Power                       7.295              Montgomery
# 34688    General Purpose                        0.25                Colleton
# 34689          Education                       0.974              Crittenden
# 34690         Healthcare                       1.465                Cuyahoga
# 34691    General Purpose                        0.03                Herkimer
# 34692    General Purpose                        0.52                   Essex
# 34693        Development                         7.2         State Authority
# 34694        Development                       0.125                  Marion
# 34695            Housing                      19.825         State Authority
# 34696        Development                      10.415                Franklin
# 34697    General Purpose                       4.475               Allegheny
# 34698          Education                       2.195                  Pierce
# 34695          New Mexico Mortgage Fin Auth         State Authority    NM
# 34696                                  Ohio          State/Province    OH
# 34697  Penn Hills Municipality-Pennsylvania          City, Town Vlg    PA
# 34698                     Pierce Co SD (GA)                District    GA
# 34699                  Pierz City-Minnesota          City, Town Vlg    MN
# 34700        Russell Co Industrial Dev Auth         Local Authority    VA
# 34701            Sacramento City-California          City, Town Vlg    CA
# 34702               Shelburne-Massachusetts          City, Town Vlg    MA
# 34703                   Stark Co (Lake) LSD                District    OH
# 34704              Summers Co-West Virginia           County/Parish    WV
# 34705              Summers Co-West Virginia           County/Parish    WV
# 34706                   Tinley Park Park Dt                District    IL
# 34707                 Valley Falls-New York          City, Town Vlg    NY
# 34708                        Van Horne-Iowa          City, Town Vlg    IA
# 34709                     Walworth-New York          City, Town Vlg    NY
# 34710                   Wayne City-Nebraska          City, Town Vlg    NE
#
#       Security Type  Year                     st_cou   FIPS
# 0                GO  2012                   nj_salem  34033
# 1                GO  2012                    ne_holt  31089
# 2                GO  2012                mn_beltrami  27007
# 3                GO  2012                  ny_broome  36007
# 4                GO  2012               nj_middlesex  34023
# 5                RV  2012                  ca_solano  06095
# 6                GO  2012               wi_marinette  55075
# 7                GO  2012                  ny_putnam  36079
# 8                GO  2012             in_bartholomew  18005
# 9                RV  2012                  ca_orange  06059
# 10               GO  2012                ny_onondaga  36067
# 11               GO  2012               ma_worcester  25027
# 12               GO  2012                ar_cleburne  05023
# 13               GO  2012  ny_clinton/essex/franklin    NaN
# 14               GO  2012              ct_new london  09011
# 15               GO  2012              ct_new london  09011
# 16               GO  2012             ny_westchester  36119
# 17               GO  2012                     ks_elk  20049
# 18               RV  2012                 ky_elliott  21063
# 19               GO  2012                   tx_cooke  48097
# 20               GO  2012                  ny_nassau  36059
# 21               RV  2012                pa_franklin  42055
# 22               RV  2012                 ky_hancock  21091
# 23               GO  2012                    me_york  23031
# 24               GO  2012                    me_knox  23013
# 25               GO  2012              pa_montgomery  42091
# 26               RV  2012                  ky_marion  21155
# 27               GO  2012                   oh_union  39159
# 28               GO  2012                  ny_nassau  36059
# 29               GO  2012                  ny_monroe  36055
# ...             ...   ...                        ...    ...
# 34681            RV  1993           la_bossier/caddo    NaN
# 34682            GO  1993                   nj_union  34039
# 34683            RV  1993                  pa_beaver  42007
# 34684            GO  1993              ri_providence  44007
# 34685            RV  1993               va_albemarle  51003
# 34686            GO  1993                  ny_monroe  36055
# 34687            RV  1993              tn_montgomery  47125
# 34688            GO  1993                sc_colleton  45029
# 34689            GO  1993              ar_crittenden  05035
# 34690            RV  1993                oh_cuyahoga  39035
# 34691            GO  1993                ny_herkimer  36043
# 34692            GO  1993                   ma_essex  25009
# 34693            RV  1993         il_state authority    NaN
# 34694            RV  1993                  in_marion  18097
# 34695            RV  1993         nm_state authority    NaN
# 34696            RV  1993                oh_franklin  39049
# 34697            GO  1993               pa_allegheny  42003
# 34698            GO  1993                  ga_pierce  13229
# 34699            GO  1993                mn_morrison  27097
# 34700            RV  1993                 va_russell  51167
# 34701            RV  1993              ca_sacramento  06067
# 34702            GO  1993                ma_franklin  25011
# 34703            GO  1993           oh_stark/portage    NaN
# 34704            RV  1993                 wv_summers  54089
# 34705            RV  1993                 wv_summers  54089
# 34706            RV  1993               il_cook/will    NaN
# 34707            GO  1993              ny_rensselaer  36083
# 34708            GO  1993                     ia_nan    NaN
# 34709            GO  1993                   ny_wayne  36117
# 34710            RV  1993                   ne_wayne  31179
#
# [465391 rows x 10 columns]

# %%
dict(zip(debt[debt['FIPS'].notnull()]['FIPS'].apply(lambda x: x[:2]),debt[debt['FIPS'].notnull()]['State']))
# Out:
# {'01': 'AL',
#  '02': 'AK',
#  '04': 'AZ',
#  '05': 'AR',
#  '06': 'CA',
#  '08': 'CO',
#  '09': 'CT',
#  '10': 'DE',
#  '11': 'DC',
#  '12': 'FL',
#  '13': 'GA',
#  '15': 'HI',
#  '16': 'ID',
#  '17': 'IL',
#  '18': 'IN',
#  '19': 'IA',
#  '20': 'KS',
#  '21': 'KY',
#  '22': 'LA',
#  '23': 'ME',
#  '24': 'MD',
#  '25': 'MA',
#  '26': 'MI',
#  '27': 'MN',
#  '28': 'MS',
#  '29': 'MO',
#  '30': 'MT',
#  '31': 'NE',
#  '32': 'NV',
#  '33': 'NH',
#  '34': 'NJ',
#  '35': 'NM',
#  '36': 'NY',
#  '37': 'NC',
#  '38': 'ND',
#  '39': 'OH',
#  '40': 'OK',
#  '41': 'OR',
#  '42': 'PA',
#  '44': 'RI',
#  '45': 'SC',
#  '46': 'SD',
#  '47': 'TN',
#  '48': 'TX',
#  '49': 'UT',
#  '50': 'VT',
#  '51': 'VA',
#  '53': 'WA',
#  '54': 'WV',
#  '55': 'WI',
#  '56': 'WY'}

# %%
print 'Total number of issues:',len(debt)
print 'Number of issues that still do not have a FIPS code:',len(debt[debt['FIPS'].isnull()])
print 'Proportion of issues that still do not have a FIPS code:',len(debt[debt['FIPS'].isnull()])/float(len(debt))
# Out:
# Total number of issues: 465391
# Number of issues that still do not have a FIPS code: 101639
# Proportion of issues that still do not have a FIPS code: 0.218394855079

# %% [markdown]
# ### State Issuers

# %% [markdown]
# Ok, that got about three quarters of the records.  Let's try to get the rest.  Many issuers come from the `State Authority` or the `State` outright.  Pretty much, if `State` is anywhere in the description, no single county can be affiliated with the issue. So, let's allocate the state FIPS to all of them.

# %%
#Capture states
states=sorted(set(debt['State']))[1:]

#For each state...
for st in states:
    #...capture the keys associated with that state...
    st_keys=[item for item in fips_dict.items() if str(st).lower()+'_' in item[0]]
    try:
        #...extract the state portion of the value associated with the first member of the list...
        st_key_part=st_keys[0][1][:2]
        #...and assign the state fips code
        state_in_desc=((debt['Issuer Type Description'].apply(lambda x: 'State' in str(x))) |\
                       (debt['County'].apply(lambda x: 'State' in str(x))))
        st_mask=(debt['State']==st) & (state_in_desc)
        debt.ix[st_mask,'FIPS']=st_key_part+'000'
#         debt.ix[(debt['State']==st) & (debt['County']=='State'),'FIPS']=st_key_part+'000'
    except:
        print 'Problem state >>> ',st

# 316          Oregon School Boards Association         State Authority    OR
# 349                Ohio Public Fac Commission         State Authority    OH
# 350                Ohio Public Fac Commission         State Authority    OH
# 351                Ohio Public Fac Commission         State Authority    OH
# 398         Missouri Assoc of Rural Education         State Authority    MO
# 404    Puerto Rico Aqueduct & Sewer Authority         State Authority    PR
# 420           California Health Facs Fin Auth         State Authority    CA
# 456         Missouri Assoc of Rural Education         State Authority    MO
# 459          Nebraska Municipal Energy Agency         State Authority    NE
# 460           New Jersey Hlth Care Fac Fin Au         State Authority    NJ
# 473                 Port Authority of NY & NJ         State Authority    NY
# 487             Texas Water Development Board         State Authority    TX
# 488             Texas Water Development Board         State Authority    TX
# 512          Idaho Bond Bank Authority (IBBA)         State Authority    ID
# 513                Idaho Water Resource Board         State Authority    ID
# 514                Idaho Water Resource Board         State Authority    ID
# 515                         Indiana Bond Bank         State Authority    IN
# 521            Maine Hlth & Hghr Ed Facs Auth         State Authority    ME
# 528            Massachusetts Housing Fin Agcy         State Authority    MA
# 536         Missouri Assoc of Rural Education         State Authority    MO
# 540          Oregon School Boards Association         State Authority    OR
# ...                                       ...                     ...   ...
# 34384         Kentucky School Facs Const Comm         State Authority    KY
# 34400       Missouri Assoc of Rural Education         State Authority    MO
# 34401       Missouri Assoc of Rural Education         State Authority    MO
# 34404            New Jersey Economic Dev Auth         State Authority    NJ
# 34426        Alabama Industrial Dev Authority         State Authority    AL
# 34453                    Idaho Housing Agency         State Authority    ID
# 34454            Indiana Development Fin Auth         State Authority    IN
# 34466                 Michigan Strategic Fund         State Authority    MI
# 34470                      NYS Dorm Authority         State Authority    NY
# 34471         New Jersey Hlth Care Fac Fin Au         State Authority    NJ
# 34479          PR Ind Tourist Ed Med Env Auth         State Authority    PR
# 34493        Texas Dept of Hsg & Comm Affairs         State Authority    TX
# 34510        California Rural Home Mtg Fin Au         State Authority    CA
# 34511        California Statewide CDA (CSCDA)         State Authority    CA
# 34512        California Statewide CDA (CSCDA)         State Authority    CA
# 34543                   NYS Thruway Authority         State Authority    NY
# 34571             Utah Housing Finance Agency         State Authority    UT
# 34572        Virginia Housing Dev Auth (VHDA)         State Authority    VA
# 34573        Virginia Housing Dev Auth (VHDA)         State Authority    VA
# 34574        Virginia Small Business Fin Auth         State Authority    VA
# 34575        Virginia Small Business Fin Auth         State Authority    VA
# 34582         California Housing Finance Agcy         State Authority    CA
# 34641                  Iowa Finance Authority         State Authority    IA
# 34645            New Jersey Economic Dev Auth         State Authority    NJ
# 34646               Oklahoma Dev Finance Auth         State Authority    OK
# 34647        Oregon School Boards Association         State Authority    OR
# 34672                 Michigan Strategic Fund         State Authority    MI
# 34673                      NYS Dorm Authority         State Authority    NY
# 34693           Illinois Development Fin Auth         State Authority    IL
# 34695            New Mexico Mortgage Fin Auth         State Authority    NM
#
#       Security Type  Year              st_cou   FIPS
# 61               RV  2012  mo_state authority  29000
# 104              RV  2012  mo_state authority  29000
# 136              GO  2012  fl_state authority  12000
# 164              RV  2012  pa_state authority  42000
# 190              RV  2012  va_state authority  51000
# 252              RV  2012  ri_state authority  44000
# 270              RV  2012  az_state authority  04000
# 277              RV  2012  ca_state authority  06000
# 314              RV  2012  ok_state authority  40000
# 316              RV  2012  or_state authority  41000
# 349              GO  2012  oh_state authority  39000
# 350              GO  2012  oh_state authority  39000
# 351              GO  2012  oh_state authority  39000
# 398              RV  2012  mo_state authority  29000
# 404              GO  2012  pr_state authority  72000
# 420              RV  2012  ca_state authority  06000
# 456              RV  2012  mo_state authority  29000
# 459              RV  2012  ne_state authority  31000
# 460              RV  2012  nj_state authority  34000
# 473              RV  2012  ny_state authority  36000
# 487              GO  2012  tx_state authority  48000
# 488              GO  2012  tx_state authority  48000
# 512              RV  2012  id_state authority  16000
# 513              RV  2012  id_state authority  16000
# 514              RV  2012  id_state authority  16000
# 515              RV  2012  in_state authority  18000
# 521              RV  2012  me_state authority  23000
# 528              GO  2012  ma_state authority  25000
# 536              RV  2012  mo_state authority  29000
# 540              RV  2012  or_state authority  41000
# ...             ...   ...                 ...    ...
# 34384            RV  1993  ky_state authority  21000
# 34400            RV  1993  mo_state authority  29000
# 34401            RV  1993  mo_state authority  29000
# 34404            RV  1993  nj_state authority  34000
# 34426            RV  1993  al_state authority  01000
# 34453            RV  1993  id_state authority  16000
# 34454            RV  1993  in_state authority  18000
# 34466            RV  1993  mi_state authority  26000
# 34470            RV  1993  ny_state authority  36000
# 34471            RV  1993  nj_state authority  34000
# 34479            RV  1993  pr_state authority  72000
# 34493            RV  1993  tx_state authority  48000
# 34510            RV  1993  ca_state authority  06000
# 34511            RV  1993  ca_state authority  06000
# 34512            RV  1993  ca_state authority  06000
# 34543            RV  1993  ny_state authority  36000
# 34571            RV  1993  ut_state authority  49000
# 34572            RV  1993  va_state authority  51000
# 34573            RV  1993  va_state authority  51000
# 34574            RV  1993  va_state authority  51000
# 34575            RV  1993  va_state authority  51000
# 34582            RV  1993  ca_state authority  06000
# 34641            RV  1993  ia_state authority  19000
# 34645            RV  1993  nj_state authority  34000
# 34646            RV  1993  ok_state authority  40000
# 34647            RV  1993  or_state authority  41000
# 34672            RV  1993  mi_state authority  26000
# 34673            RV  1993  ny_state authority  36000
# 34693            RV  1993  il_state authority  17000
# 34695            RV  1993  nm_state authority  35000
#
# [41979 rows x 10 columns]

# %%
print 'Total number of issues:',len(debt)
print 'Number of issues that still do not have a FIPS code:',len(debt[debt['FIPS'].isnull()])
print 'Proportion of issues that still do not have a FIPS code:',len(debt[debt['FIPS'].isnull()])/float(len(debt))
# Out:
# Total number of issues: 465391
# Number of issues that still do not have a FIPS code: 51254
# Proportion of issues that still do not have a FIPS code: 0.110131051095

# %% [markdown]
# ### Using Google to Capture Colleges and Some of the Remaining Misses

# %% [markdown]
# Ok, we still have a number of misses.  I considered just taking the first element from hybrid county descriptions, but sometimes the subsequent positions are meaningful.  For example, we wouldn't necessarily get Bronx County if we only captures New York from `New York/Bronx/Kings`.  There are too many to do by hand, so we are going to utilize the Google Maps API to cut down the current gap.  There are a couple lists we have to sort through:
#
# 1. Issues with some version of `College or University` as the county description.  We will key on issuer names in this scenario.
# 2. County descriptions that did not have a direct match in the FIPS data.
#
# The API does not spit out FIPS codes, but it does provide regular county names.  We can construct new keys based upon the state_county combination that hopefully are members of the FIPS mapping dictionary.  First, let's identify our lists.

# %%
#Capture list of college issuers
college_pairs=zip(debt[debt['County'].apply(lambda x: 'College' in str(x))]['Issuer'],
                  debt[debt['County'].apply(lambda x: 'College' in str(x))]['State'])
college_issues=list(set(college_pairs))

#Create masks for other county descriptions (excluding authorities)
no_st_auth=((debt['Issuer Type Description'].apply(lambda x: 'State' not in str(x))) |\
            (debt['County'].apply(lambda x: 'State' not in str(x))))
no_loc_auth=(debt['County'].apply(lambda x: 'Local' not in str(x)))
no_college=(debt['County'].apply(lambda x: 'College' not in str(x)))

#Capture list of random issuers
rando_pairs=zip(debt[no_st_auth & no_loc_auth & no_college]['County'],
                debt[no_st_auth & no_loc_auth & no_college]['State'])
rando_issues=list(set(rando_pairs))

len(college_issues)
# Out:
# 381

# %% [markdown]
# Now we need a function to implement the geocoding...

# %%
def county_id(point_of_interest,state=None):
    '''Function returns state_county concatenation of a given point of interest.'''
    #Set base URL
    url = 'https://maps.googleapis.com/maps/api/geocode/json'
    #Set parameters for call to API (which are appended to the base)
    params = {'sensor': 'false',
              'address': point_of_interest,
              'key':'Get your own key son!'}
    #Make call to API
    r = requests.get(url, params=params)
    #Capture results
    results = r.json()['results']
#     print results
#     print len(results)
    #If a state is provided...
    if state != None:
        #...for each hit...
        for r in results:
            #...capture the state and county...
            res_st=[comp['short_name'] for comp in r['address_components'] \
                    if comp['types'][0]=='administrative_area_level_1']
            res_co=[comp['short_name'] for comp in r['address_components'] \
                    if comp['types'][0]=='administrative_area_level_2']
            #...if the state matches...
            if res_st[0]==state:
                #...return the county...
                return (res_st[0]+'_'+res_co[0].replace(' County','')).lower()
    else:
        #Capture the state and county
        res_st=[comp['short_name'] for comp in results[0]['address_components'] \
                if comp['types'][0]=='administrative_area_level_1']
        res_co=[comp['short_name'] for comp in results[0]['address_components'] \
                if comp['types'][0]=='administrative_area_level_2']
        #Capture county from the first hit
        return (res_st[0]+'_'+res_co[0].replace(' County','')).lower()

# %% [markdown]
# Now, let's roll through these places and capture (hopefully) better keys.  Note that this takes awhile, so we will store our results and read it back the next time.

# %%
# print 'Number of College Issues:',len(college_issues)
# print 'Number of Random Issues:',len(rando_issues)

# #Create dicts for colleges and the randos
# college_map={}
# rando_map={}

# #Create containers for misses
# college_miss=[]
# rando_miss=[]

# print '***INITIALIZING COLLEGE LOOP***'
# #For each college...
# for i,college in enumerate(college_issues):
#     if i%50==0:
#         print i,'|',college
#     try:
#         #...capture the new key...
#         college_map.update({college[0]:county_id(college[0]+' '+college[1])})
#     except:
#         college_miss.append(college)

# print '\n\n***INITIALIZING COLLEGE LOOP***'
# #For each random issuer...
# for i,rando in enumerate(rando_issues):
#     if i%50==0:
#         print i,'|',rando
#     try:
#         #...capture the new key...
#         rando_map.update({rando[0]:county_id(rando[0]+' '+rando[1])})
#     except:
#         rando_miss.append(rando)

# %% [markdown]
# We can capture the successful API calls in two series.

# %%
# #Capture in series
# college_new_keys=Series(college_map)
# rando_new_keys=Series(rando_map)

# #Remove special characters
# ##Tildes
# college_new_keys=college_new_keys.apply(lambda x: x.encode('utf-8').replace('\xc3\xb1','n'))
# rando_new_keys=rando_new_keys.apply(lambda x: x.encode('utf-8').replace('\xc3\xb1','n'))

# #Write to disk
# college_new_keys.to_csv('../data/g_api_college.csv')
# rando_new_keys.to_csv('../data/g_api_rando.csv')

# len(college_new_keys),len(rando_new_keys)

# %%
#Read from disk
college_new_keys=pd.read_csv('../data/g_api_college.csv',names=['desc','key'])
rando_new_keys=pd.read_csv('../data/g_api_rando.csv',names=['desc','key'])

#Set indices
college_new_keys.set_index('desc',inplace=True)
rando_new_keys.set_index('desc',inplace=True)

college_new_keys.head()
# Out:
#                                           key
# desc
# Akron University                    oh_summit
# Alabama State Board of Education    al_clarke
# Alabama State University           al_madison
# Arizona State University          az_maricopa
# Arizona Western College           az_maricopa

# %% [markdown]
# We need to map in these new keys, but I would like to preserve the ability to compare the old and new keys.  Consequently, we will create a new `st_cou_g1` variable that will hold the new keys, and a composite variable `st_cou_final` that holds the keys from `st_cou_g1` where they exist, and `st_cou` where they don't.  Note that these should only be assigned where the FIPS code is currently missing.

# %%
#Define mask
nofips=(debt['FIPS'].isnull())

#Generate new var
debt['st_cou_g1']=''

#Fill in random new keys
debt.ix[nofips,'st_cou_g1']=debt.ix[nofips]['County'].map(rando_new_keys['key'])

#Fill in college new keys
no_st_cou_g1=(debt['st_cou_g1'].isnull())
debt.ix[nofips & no_st_cou_g1,'st_cou_g1']=debt.ix[nofips & no_st_cou_g1]['Issuer'].map(college_new_keys['key'])

#Create composite variable
debt['st_cou_final']=np.where(debt['st_cou_g1'].notnull(),debt['st_cou_g1'],debt['st_cou'])

#For records without FIPS, use st_cou_final to map in a code
debt.ix[nofips,'FIPS']=debt.ix[nofips]['st_cou_final'].map(fips_dict)

debt[debt['FIPS'].isnull()]
# Out:
#         Bond Buyer UOP30 Amount of Maturity ($ mils)  \
# 93             Education                       3.420
# 214            Education                      11.495
# 265            Education                       4.345
# 268           Healthcare                       3.730
# 359            Education                       1.800
# 462            Utilities                       0.125
# 546            Education                       1.965
# 593            Education                       2.650
# 664       Electric Power                       7.120
# 665       Electric Power                      76.665
# 675            Education                       5.070
# 747            Education                      34.695
# 808      General Purpose                       5.235
# 825      General Purpose                       2.795
# 843            Education                      15.470
# 953            Education                       5.785
# 983            Education                       4.060
# 1015           Education                      29.815
# 1093           Education                      25.845
# 1116           Education                      20.685
# 1123           Education                       2.780
# 1131           Education                      12.555
# 1133           Education                      51.500
# 1227     General Purpose                       3.470
# 1275           Education                       5.925
# 1276           Education                      35.580
# 1309           Education                       3.000
# 1327           Education                       1.320
# 1423   Public Facilities                       1.144
# 1452           Education                       2.000
# ...                  ...                         ...
# 33776          Utilities                       6.945
# 33792          Education                        7.09
# 34162                  Valdez/Cordova                     Valdez City-Alaska
# 34175          Travis/Williamson/Hays                      Austin City-Texas
# 34180                             NaN           Clarksville Comm School Corp
# 34209                             NaN         Keystone Health Resources Corp
# 34230      Canadian/Cleveland/McClain         Oklahoma City Airport Trustees
# 34231      Canadian/Cleveland/McClain         Oklahoma City Airport Trustees
# 34232      Canadian/Cleveland/McClain         Oklahoma City Airport Trustees
# 34274                 Local Authority          Assoc of Bay Area Govt (ABAG)
# 34276          Travis/Williamson/Hays                      Austin City-Texas
# 34309                 Walworth/Racine          Honey Lake Protect & Rehab Dt
# 34447                             NaN                    Fairchild-Wisconsin
# 34535                McLennan/Coryell                    McGregor City-Texas
# 34546                             NaN       New Harmony School Building Corp
# 34547                             NaN               North Cumberland Fire Dt
# 34554                             NaN                  Presbyterian Home Inc
# 34569                             NaN       Tulare Lake Basin Wtr Storage Dt
# 34610                  Valdez/Cordova                     Valdez City-Alaska
# 34620            Indiana/Westmoreland  Indiana Co (Blairsville-Saltsburg) SD
# 34632                             NaN                   Avondale Housing Inc
# 34633                             NaN                   Avondale Housing Inc
# 34681                   Bossier/Caddo           Shreveport Housing Authority
# 34706                       Cook/Will                    Tinley Park Park Dt
# 34708                             NaN                         Van Horne-Iowa
#
#       Issuer Type Description State Security Type  Year  \
# 93            College or Univ    NE            RV  2012
# 214           College or Univ    CO            RV  2012
# 265           College or Univ    AR            RV  2012
# 268           Local Authority    CA            RV  2012
# 359                  District    IL            GO  2012
# 462                  District    TX            GO  2012
# 546                  District    WI            GO  2012
# 593                  District    WI            GO  2012
# 664           Local Authority    CA            RV  2012
# 665           Local Authority    CA            RV  2012
# 675                  District    MI            GO  2012
# 747                  District    CO            GO  2012
# 808            City, Town Vlg    IL            GO  2012
# 825                  District    FL            GO  2012
# 843                  District    WI            GO  2012
# 953                  District    MI            GO  2012
# 983                  District    MI            GO  2012
# 1015          College or Univ    ME            RV  2012
# 1093          College or Univ    IA            RV  2012
# 1116                 District    LA            GO  2012
# 1123                 District    NY            GO  2012
# 1131          College or Univ    IA            RV  2012
# 1133          College or Univ    WA            RV  2012
# 1227          Local Authority    IN            RV  2012
# 1275          College or Univ    FL            RV  2012
# 1276          College or Univ    FL            RV  2012
# 1309                 District    IL            GO  2012
# 1327                 District    CO            GO  2012
# 1423                 District    IL            GO  2012
# 1452                 District    WI            GO  2012
# ...                       ...   ...           ...   ...
# 33776         Local Authority    MT            RV  1993
# 33792         College or Univ    AK            RV  1993
# 33869                District    WI            GO  1993
# 33981          City, Town Vlg    OH            GO  1993
# 34043          City, Town Vlg    AK            GO  1993
# 34061          City, Town Vlg    LA            GO  1993
# 34111         College or Univ    IA            RV  1993
# 34162          City, Town Vlg    AK            RV  1993
# 34175          City, Town Vlg    TX            RV  1993
# 34180                District    IN            GO  1993
# 34209           Direct Issuer    PA            RV  1993
# 34230         Local Authority    OK            RV  1993
# 34231         Local Authority    OK            RV  1993
# 34232         Local Authority    OK            RV  1993
# 34274         Local Authority    CA            RV  1993
# 34276          City, Town Vlg    TX            RV  1993
# 34309                District    WI            RV  1993
# 34447          City, Town Vlg    WI            RV  1993
# 34535          City, Town Vlg    TX            RV  1993
# 34546                District    IN            GO  1993
# 34547                District    RI            GO  1993
# 34554           Direct Issuer    PA            RV  1993
# 34569                District    CA            RV  1993
# 34610          City, Town Vlg    AK            RV  1993
# 34620                District    PA            GO  1993
# 34632           Direct Issuer    IN            RV  1993
# 34633           Direct Issuer    IN            RV  1993
# 34681         Local Authority    LA            RV  1993
# 34706                District    IL            RV  1993
# 34708          City, Town Vlg    IA            GO  1993
#
#                                   st_cou FIPS                st_cou_g1  \
# 93              ne_college or university  NaN                      NaN
# 214             co_college or university  NaN                      NaN
# 265             ar_college or university  NaN                      NaN
# 268                   ca_local authority  NaN                      NaN
# 359        il_livingston/grundy/la salle  NaN                      NaN
# 462                         tx_northwest  NaN                      NaN
# 546                    wi_polk/st. croix  NaN                      NaN
# 593             wi_barron/dunn/st. croix  NaN              wi_st croix
# 664     ca_stanislaus/alameda/placer/etc  NaN                      NaN
# 665     ca_stanislaus/alameda/placer/etc  NaN                      NaN
# 675           mi_saginaw/midland/gratiot  NaN                      NaN
# 747              co_boulder/larimer/weld  NaN                      NaN
# 808                         il_cook/will  NaN                      NaN
# 825                          fl_district  NaN           rakhine_sittwe
# 843                  wi_pierce/st. croix  NaN                      NaN
# 953                 mi_washtenaw/jackson  NaN                      NaN
# 983                  mi_macomb/st. clair  NaN                      NaN
# 1015            me_college or university  NaN                      NaN
# 1093                  ia_college or univ  NaN                      NaN
# 1116                   la_rapides parish  NaN        la_rapides parish
# 1123      ny_schoharie/montgomery/otsego  NaN                      NaN
# 1131            ia_college or university  NaN                      NaN
# 1133            wa_college or university  NaN                      NaN
# 1227                  in_local authority  NaN                      NaN
# 1275            fl_college or university  NaN                      NaN
# 1276            fl_college or university  NaN                      NaN
# 1309   il_kankakee/will/grudy/livingston  NaN                      NaN
# 1327             co_otero/crowley/pueblo  NaN                      NaN
# 1423                      il_dupage/will  NaN                      NaN
# 1452          wi_racine/kenosha/walworth  NaN                      NaN
# ...                                  ...  ...                      ...
# 33776                             mt_nan  NaN                      NaN
# 33792                       ak_fairbanks  NaN  ak_fairbanks north star
# 33869                   wi_sauk/columbia  NaN                      NaN
# 33981                             oh_nan  NaN                      NaN
# 34043                     ak_north slope  NaN           ak_north slope
# 34061                   la_bossier/caddo  NaN        la_bossier parish
# 34111                 ia_college or univ  NaN                      NaN
# 34162                  ak_valdez/cordova  NaN        ak_valdez-cordova
# 34175          tx_travis/williamson/hays  NaN                      NaN
# 34180                             in_nan  NaN                      NaN
# 34209                             pa_nan  NaN                      NaN
# 34230      ok_canadian/cleveland/mcclain  NaN                      NaN
# 34231      ok_canadian/cleveland/mcclain  NaN                      NaN
# 34232      ok_canadian/cleveland/mcclain  NaN                      NaN
# 34274                 ca_local authority  NaN                      NaN
# 34276          tx_travis/williamson/hays  NaN                      NaN
# 34309                 wi_walworth/racine  NaN                      NaN
# 34447                             wi_nan  NaN                      NaN
# 34535                tx_mclennan/coryell  NaN                      NaN
# 34546                             in_nan  NaN                      NaN
# 34547                             ri_nan  NaN                      NaN
# 34554                             pa_nan  NaN                      NaN
# 34569                             ca_nan  NaN                      NaN
# 34610                  ak_valdez/cordova  NaN        ak_valdez-cordova
# 34620            pa_indiana/westmoreland  NaN                      NaN
# 34632                             in_nan  NaN                      NaN
# 34633                             in_nan  NaN                      NaN
# 34681                   la_bossier/caddo  NaN        la_bossier parish
# 34706                       il_cook/will  NaN                      NaN
# 34708                             ia_nan  NaN                      NaN
#
#                             st_cou_final
# 93              ne_college or university
# 214             co_college or university
# 265             ar_college or university
# 268                   ca_local authority
# 359        il_livingston/grundy/la salle
# 462                         tx_northwest
# 546                    wi_polk/st. croix
# 593                          wi_st croix
# 664     ca_stanislaus/alameda/placer/etc
# 665     ca_stanislaus/alameda/placer/etc
# 675           mi_saginaw/midland/gratiot
# 747              co_boulder/larimer/weld
# 808                         il_cook/will
# 825                       rakhine_sittwe
# 843                  wi_pierce/st. croix
# 953                 mi_washtenaw/jackson
# 983                  mi_macomb/st. clair
# 1015            me_college or university
# 1093                  ia_college or univ
# 1116                   la_rapides parish
# 1123      ny_schoharie/montgomery/otsego
# 1131            ia_college or university
# 1133            wa_college or university
# 1227                  in_local authority
# 1275            fl_college or university
# 1276            fl_college or university
# 1309   il_kankakee/will/grudy/livingston
# 1327             co_otero/crowley/pueblo
# 1423                      il_dupage/will
# 1452          wi_racine/kenosha/walworth
# ...                                  ...
# 33776                             mt_nan
# 33792            ak_fairbanks north star
# 33869                   wi_sauk/columbia
# 33981                             oh_nan
# 34043                     ak_north slope
# 34061                  la_bossier parish
# 34111                 ia_college or univ
# 34162                  ak_valdez-cordova
# 34175          tx_travis/williamson/hays
# 34180                             in_nan
# 34209                             pa_nan
# 34230      ok_canadian/cleveland/mcclain
# 34231      ok_canadian/cleveland/mcclain
# 34232      ok_canadian/cleveland/mcclain
# 34274                 ca_local authority
# 34276          tx_travis/williamson/hays
# 34309                 wi_walworth/racine
# 34447                             wi_nan
# 34535                tx_mclennan/coryell
# 34546                             in_nan
# 34547                             ri_nan
# 34554                             pa_nan
# 34569                             ca_nan
# 34610                  ak_valdez-cordova
# 34620            pa_indiana/westmoreland
# 34632                             in_nan
# 34633                             in_nan
# 34681                  la_bossier parish
# 34706                       il_cook/will
# 34708                             ia_nan
#
# [12763 rows x 12 columns]

# %%
print 'Total number of issues:',len(debt)
print 'Number of issues that still do not have a FIPS code:',len(debt[debt['FIPS'].isnull()])
print 'Proportion of issues that still do not have a FIPS code:',len(debt[debt['FIPS'].isnull()])/float(len(debt))
# Out:
# Total number of issues: 465391
# Number of issues that still do not have a FIPS code: 12763
# Proportion of issues that still do not have a FIPS code: 0.0274242518656

# %% [markdown]
# ### Dealing with composite `County` descriptions

# %% [markdown]
# We are down to about 37,000 records with no FIPS codes out of 465,000.  How many of these are because of compound county descriptions (e.g. `New York/Bronx/Kings`)?

# %%
debt[debt['FIPS'].isnull()]['st_cou_final'].apply(lambda x: '/' in str(x)).sum()
# Out:
# 4440

# %% [markdown]
# Looks like we can take out roughly 60% of our misses if one of the locations an actual county name in the FIPS data.  Our approach will be to roll through the compound county descriptions, individually pair them with the associated state, and see if they show up in our keys in `fips_dict`.  While it is not always the case that a county name will show up in the `Issuer` variable, when it does, it appears to correspond with the first jurisdiction mentioned in the `County` variable.  Consequently, our rule will be to take the first match we find.

# %%
#Build mask to capture compound counties that do not have FIPS yet
nofips_compound=(debt['FIPS'].isnull()) & (debt['st_cou_final'].apply(lambda x: '/' in str(x)))

#Define function that returns FIPS for county description components
def composite_match(s,delim='/'):
    #If the first jurisdiction is a county in the FIPS set...
    if s.split(delim)[0] in fips_dict.keys():
        #...return the appropriate FIPS code...
        return fips_dict[s.split(delim)[0]]
    #...otherwise...
    else:
        #...capture state...
        s_st=s[:3]
        #...capture other jurisdictions...
        s_jur=s[3:]
        #...and for each remaining jurisdiction...
        for j in s_jur.split(delim):
            #...if one of them shows up in FIPS...
            if s_st+j in fips_dict.keys():
                #...return the appropriate FIPS code
                return fips_dict[s_st+j]
            
#Assign FIPS codes to composite county records
debt.ix[nofips_compound,'FIPS']=debt.ix[nofips_compound]['st_cou_final'].apply(lambda x: composite_match(x))

#Redefine mask for backslash as the delimeter
nofips_compound=(debt['FIPS'].isnull()) & (debt['st_cou_final'].apply(lambda x: '\\' in str(x)))

#Assign FIPS codes to composite county records
debt.ix[nofips_compound,'FIPS']=debt.ix[nofips_compound]['st_cou_final'].apply(lambda x: \
                                                                               composite_match(x,delim='\\'))

debt[debt['FIPS'].isnull()]
# Out:
#         Bond Buyer UOP30 Amount of Maturity ($ mils)                   County  \
# 93             Education                       3.420    College or University
# 214            Education                      11.495    College or University
# 265            Education                       4.345    College or University
# 268           Healthcare                       3.730          Local Authority
# 462            Utilities                       0.125                Northwest
# 593            Education                       2.650    Barron/Dunn/St. Croix
# 825      General Purpose                       2.795                 District
# 1015           Education                      29.815    College or University
# 1093           Education                      25.845          College or Univ
# 1116           Education                      20.685           Rapides Parish
# 1131           Education                      12.555    College or University
# 1133           Education                      51.500    College or University
# 1227     General Purpose                       3.470          Local Authority
# 1275           Education                       5.925    College or University
# 1276           Education                      35.580    College or University
# 1463           Education                       0.800                 La Salle
# 1544           Education                       0.930  Gibbons/Fairfax/Wintrop
# 1549           Education                      23.355    College or University
# 1682     General Purpose                     120.000                Anchorage
# 1738           Education                       1.625    College or University
# 2290           Education                      31.670                Fairbanks
# 2567           Education                      14.000  East Baton Rouge Parish
# 2864      Transportation                       5.770        Matanuska-Susitna
# 2865           Education                      91.770        Matanuska-Susitna
# 2901           Education                      56.965    College or University
# 2923           Education                      11.170    College or University
# 3069      Electric Power                      30.330            Direct Issuer
# 3070      Electric Power                      24.100            Direct Issuer
# 3073           Education                       4.365    College or University
# 3076           Education                      11.910          College or Univ
# ...                  ...                         ...                      ...
# 33322          Education                       3.585    College or University
# 33352          Education                          27    College or University
# 33360         Healthcare                       10.76                      NaN
# 33382    General Purpose                       7.045                      NaN
# 33437  Public Facilities                        3.58                      NaN
# 33438  Public Facilities                       3.785                      NaN
# 33515          Utilities                        0.69                      NaN
# 33625          Utilities                         0.5                      NaN
# 33634          Education                         0.8                      NaN
# 33772          Utilities                       8.685                      NaN
# 33776          Utilities                       6.945                      NaN
# 33792          Education                        7.09                Fairbanks
# 33981  Public Facilities                       0.275                      NaN
# 34043    General Purpose                      49.105              North Slope
# 34061    General Purpose                          19            Bossier/Caddo
# 34111          Education                       5.295          College or Univ
# 34162     Transportation                          60           Valdez/Cordova
# 34180          Education                         0.8                      NaN
# 34209         Healthcare                         6.3                      NaN
# 34274    General Purpose                       0.904          Local Authority
# 34447         Healthcare                         0.4                      NaN
# 34546          Education                       1.175                      NaN
# 34547  Public Facilities                       0.498                      NaN
# 34554         Healthcare                           5                      NaN
# 34569          Utilities                         2.7                      NaN
# 34610     Transportation                      128.23           Valdez/Cordova
# 34632            Housing                         0.2                      NaN
# 34633            Housing                        0.45                      NaN
# 34681            Housing                        0.23            Bossier/Caddo
# 34708  Public Facilities                        0.25                      NaN
#
#                                      Issuer Issuer Type Description State  \
# 93         Central Comm Coll Bd of Governor         College or Univ    NE
# 214    Colorado St Bd of Comm Coll & Occ Ed         College or Univ    CO
# 265         Univ of Arkansas Bd of Trustees         College or Univ    AR
# 268          ABAG Fin Au for Nonprofit Corp         Local Authority    CA
# 462             Northwest Harris Co MUD #19                District    TX
# 593                Dunn Co (Boyceville) CSD                District    WI
# 825             Interlaken Community Dev Dt                District    FL
# 1015             University of Maine System         College or Univ    ME
# 1093            Iowa State Board of Regents         College or Univ    IA
# 1116      Rapides Parish (Pineville) SD #52                District    LA
# 1131           University of Iowa Facs Corp         College or Univ    IA
# 1133            Washington State University         College or Univ    WA
# 1227      Evansville-Vanderburgh Co Bldg Au         Local Authority    IN
# 1275       Florida St University Fin Assist         College or Univ    FL
# 1276       Florida St University Fin Assist         College or Univ    FL
# 1463            La Salle Co (Peru) ESD #124                District    IL
# 1544                      Gibbons ISD #2365                District    MN
# 1549    Lake Superior St Univ Bd of Regents         College or Univ    MI
# 1682                  Anchorage City-Alaska          City, Town Vlg    AK
# 1738          Northwestern Michigan College         College or Univ    MI
# 2290                   University of Alaska         College or Univ    AK
# 2567                         Zachary CSD #1                District    LA
# 2864          Matanuska-Susitna Boro-Alaska          City, Town Vlg    AK
# 2865          Matanuska-Susitna Boro-Alaska          City, Town Vlg    AK
# 2901        Univ of Arkansas Bd of Trustees         College or Univ    AR
# 2923      Univ of Alabama Board of Trustees         College or Univ    AL
# 3069                       Energy Northwest           Direct Issuer    WA
# 3070                       Energy Northwest           Direct Issuer    WA
# 3073              Grand Rapids Comm College         College or Univ    MI
# 3076            Iowa State Board of Regents         College or Univ    IA
# ...                                     ...                     ...   ...
# 33322      Michigan Tech Univ Bd of Control         College or Univ    MI
# 33352      SW Texas St Univ Board of Regent         College or Univ    TX
# 33360                Tri-City Hospital Auth         Local Authority    GA
# 33382       Central California Pub Fin Auth         Local Authority    CA
# 33437       East Texas Criminal Justice Fac         Local Authority    TX
# 33438       East Texas Criminal Justice Fac         Local Authority    TX
# 33515          Bear Lake Special Service Dt                District    UT
# 33625      East Central Oklahoma Water Auth         Local Authority    OK
# 33634                  Greater Lawrence RSD                District    MI
# 33772            San Juan Suburban Water Dt                District    CA
# 33776                  Silver Bow Water Inc         Local Authority    MT
# 33792                  University of Alaska         College or Univ    AK
# 33981                        Brady Twp-Ohio          City, Town Vlg    OH
# 34043               North Slope Boro-Alaska          City, Town Vlg    AK
# 34061             Shreveport City-Louisiana          City, Town Vlg    LA
# 34111           Iowa State Board of Regents         College or Univ    IA
# 34162                    Valdez City-Alaska          City, Town Vlg    AK
# 34180          Clarksville Comm School Corp                District    IN
# 34209        Keystone Health Resources Corp           Direct Issuer    PA
# 34274         Assoc of Bay Area Govt (ABAG)         Local Authority    CA
# 34447                   Fairchild-Wisconsin          City, Town Vlg    WI
# 34546      New Harmony School Building Corp                District    IN
# 34547              North Cumberland Fire Dt                District    RI
# 34554                 Presbyterian Home Inc           Direct Issuer    PA
# 34569      Tulare Lake Basin Wtr Storage Dt                District    CA
# 34610                    Valdez City-Alaska          City, Town Vlg    AK
# 34632                  Avondale Housing Inc           Direct Issuer    IN
# 34633                  Avondale Housing Inc           Direct Issuer    IN
# 34681          Shreveport Housing Authority         Local Authority    LA
# 34708                        Van Horne-Iowa          City, Town Vlg    IA
#
#       Security Type  Year                      st_cou  FIPS  \
# 93               RV  2012    ne_college or university   NaN
# 214              RV  2012    co_college or university   NaN
# 265              RV  2012    ar_college or university   NaN
# 268              RV  2012          ca_local authority   NaN
# 462              GO  2012                tx_northwest   NaN
# 593              GO  2012    wi_barron/dunn/st. croix   NaN
# 825              GO  2012                 fl_district   NaN
# 1015             RV  2012    me_college or university   NaN
# 1093             RV  2012          ia_college or univ   NaN
# 1116             GO  2012           la_rapides parish   NaN
# 1131             RV  2012    ia_college or university   NaN
# 1133             RV  2012    wa_college or university   NaN
# 1227             RV  2012          in_local authority   NaN
# 1275             RV  2012    fl_college or university   NaN
# 1276             RV  2012    fl_college or university   NaN
# 1463             GO  2012                 il_la salle   NaN
# 1544             GO  2012  mn_gibbons/fairfax/wintrop  None
# 1549             RV  2012    mi_college or university   NaN
# 1682             GO  2012                ak_anchorage   NaN
# 1738             GO  2012    mi_college or university   NaN
# 2290             RV  2012                ak_fairbanks   NaN
# 2567             GO  2012  la_east baton rouge parish   NaN
# 2864             GO  2012        ak_matanuska-susitna   NaN
# 2865             GO  2012        ak_matanuska-susitna   NaN
# 2901             RV  2012    ar_college or university   NaN
# 2923             RV  2012    al_college or university   NaN
# 3069             RV  2012            wa_direct issuer   NaN
# 3070             RV  2012            wa_direct issuer   NaN
# 3073             GO  2012    mi_college or university   NaN
# 3076             RV  2012          ia_college or univ   NaN
# ...             ...   ...                         ...   ...
# 33322            RV  1993    mi_college or university   NaN
# 33352            RV  1993    tx_college or university   NaN
# 33360            RV  1993                      ga_nan   NaN
# 33382            RV  1993                      ca_nan   NaN
# 33437            RV  1993                      tx_nan   NaN
# 33438            RV  1993                      tx_nan   NaN
# 33515            GO  1993                      ut_nan   NaN
# 33625            RV  1993                      ok_nan   NaN
# 33634            GO  1993                      mi_nan   NaN
# 33772            RV  1993                      ca_nan   NaN
# 33776            RV  1993                      mt_nan   NaN
# 33792            RV  1993                ak_fairbanks   NaN
# 33981            GO  1993                      oh_nan   NaN
# 34043            GO  1993              ak_north slope   NaN
# 34061            GO  1993            la_bossier/caddo   NaN
# 34111            RV  1993          ia_college or univ   NaN
# 34162            RV  1993           ak_valdez/cordova   NaN
# 34180            GO  1993                      in_nan   NaN
# 34209            RV  1993                      pa_nan   NaN
# 34274            RV  1993          ca_local authority   NaN
# 34447            RV  1993                      wi_nan   NaN
# 34546            GO  1993                      in_nan   NaN
# 34547            GO  1993                      ri_nan   NaN
# 34554            RV  1993                      pa_nan   NaN
# 34569            RV  1993                      ca_nan   NaN
# 34610            RV  1993           ak_valdez/cordova   NaN
# 34632            RV  1993                      in_nan   NaN
# 34633            RV  1993                      in_nan   NaN
# 34681            RV  1993            la_bossier/caddo   NaN
# 34708            GO  1993                      ia_nan   NaN
#
#                         st_cou_g1                st_cou_final
# 93                            NaN    ne_college or university
# 214                           NaN    co_college or university
# 265                           NaN    ar_college or university
# 268                           NaN          ca_local authority
# 462                           NaN                tx_northwest
# 593                   wi_st croix                 wi_st croix
# 825                rakhine_sittwe              rakhine_sittwe
# 1015                          NaN    me_college or university
# 1093                          NaN          ia_college or univ
# 1116            la_rapides parish           la_rapides parish
# 1131                          NaN    ia_college or university
# 1133                          NaN    wa_college or university
# 1227                          NaN          in_local authority
# 1275                          NaN    fl_college or university
# 1276                          NaN    fl_college or university
# 1463           la_la salle parish          la_la salle parish
# 1544                          NaN  mn_gibbons/fairfax/wintrop
# 1549                          NaN    mi_college or university
# 1682                 ak_anchorage                ak_anchorage
# 1738                          NaN    mi_college or university
# 2290      ak_fairbanks north star     ak_fairbanks north star
# 2567   la_east baton rouge parish  la_east baton rouge parish
# 2864         ak_matanuska-susitna        ak_matanuska-susitna
# 2865         ak_matanuska-susitna        ak_matanuska-susitna
# 2901                          NaN    ar_college or university
# 2923                          NaN    al_college or university
# 3069                          NaN            wa_direct issuer
# 3070                          NaN            wa_direct issuer
# 3073                          NaN    mi_college or university
# 3076                          NaN          ia_college or univ
# ...                           ...                         ...
# 33322                         NaN    mi_college or university
# 33352                         NaN    tx_college or university
# 33360                         NaN                      ga_nan
# 33382                         NaN                      ca_nan
# 33437                         NaN                      tx_nan
# 33438                         NaN                      tx_nan
# 33515                         NaN                      ut_nan
# 33625                         NaN                      ok_nan
# 33634                         NaN                      mi_nan
# 33772                         NaN                      ca_nan
# 33776                         NaN                      mt_nan
# 33792     ak_fairbanks north star     ak_fairbanks north star
# 33981                         NaN                      oh_nan
# 34043              ak_north slope              ak_north slope
# 34061           la_bossier parish           la_bossier parish
# 34111                         NaN          ia_college or univ
# 34162           ak_valdez-cordova           ak_valdez-cordova
# 34180                         NaN                      in_nan
# 34209                         NaN                      pa_nan
# 34274                         NaN          ca_local authority
# 34447                         NaN                      wi_nan
# 34546                         NaN                      in_nan
# 34547                         NaN                      ri_nan
# 34554                         NaN                      pa_nan
# 34569                         NaN                      ca_nan
# 34610           ak_valdez-cordova           ak_valdez-cordova
# 34632                         NaN                      in_nan
# 34633                         NaN                      in_nan
# 34681           la_bossier parish           la_bossier parish
# 34708                         NaN                      ia_nan
#
# [8359 rows x 12 columns]

# %%
print 'Total number of issues:',len(debt)
print 'Number of issues that still do not have a FIPS code:',len(debt[debt['FIPS'].isnull()])
print 'Proportion of issues that still do not have a FIPS code:',len(debt[debt['FIPS'].isnull()])/float(len(debt))
# Out:
# Total number of issues: 465391
# Number of issues that still do not have a FIPS code: 8359
# Proportion of issues that still do not have a FIPS code: 0.0179612411929

# %% [markdown]
# So, we still have over 8000 misses, but that represents under 2% of debt issues.  That's a decent hit rate.  Here's where those misses occur.

# %%
print 'Number of counties without FIPS:',len(debt.ix[(debt['FIPS'].isnull())]['County'].value_counts())
debt.ix[(debt['FIPS'].isnull())]['County'].value_counts()
# Out:
# Number of counties without FIPS: 201
# College or University          1672
# Local Authority                 677
# College or Univ                 325
# Anchorage                       166
# La Salle                        141
# Direct Issuer                   136
# Baton Rouge                     108
# Bossier/Caddo                    75
# North Slope                      57
# Matanuska-Susitna                36
# Fairbanks No Star                32
# St. Marys                        29
# Hampton Indep City               29
# Valdez/Cordova                   27
# Barron/Dunn/St. Croix            23
# Orleans Parish                   22
# Plaquemine                       20
# Perham/Dent                      20
# District                         19
# East Baton Rouge Parish          19
# Northwest                        18
# Fairbanks                        18
# Goge                             16
# Sanilac/Lapeer/St. Clair         15
# Marshall/St. Joseph              13
# Saipan                           12
# Ft Pierce                        12
# County/Parish                    12
# James                            11
# Quachita                         11
#                                ...
# Joseph                            1
# Greensburg                        1
# Hazelwood/St. Louis               1
# East Jefferson                    1
# Village                           1
# Windsar                           1
# Big Pasture                       1
# Uncoln                            1
# Elsinore                          1
# Bay Port/Branches                 1
# Tallilah                          1
# Madison Parish                    1
# Grants/Abola                      1
# St. Tammary                       1
# Twin Falls/Cassia                 1
# Missouri                          1
# El                                1
# Greenberg                         1
# Pennsylvania                      1
# St. John The Baptist Parish       1
# Town                              1
# Pawlet/Rupert                     1
# Pierce/St. Croix/Dunn Cos         1
# Northwest Arctic                  1
# Wrangell-Petersburg               1
# Lancaser                          1
# Pointe Coupee Parish              1
# Plumes                            1
# Santa                             1
# Ruston                            1
# Name: County, dtype: int64

# %%
#Subset to debt issues with FIPS codes
debt_fips=debt[debt['FIPS'].notnull()]

#Write to disk
debt_fips.to_csv('../data/debt_w_fips.csv')

# %% [markdown]
# ## Aggregating by County and Year

# %% [markdown]
# At this point, we will drop the debt issues we do not have FIPS codes for because they cannot be merged with the institutional data.  Our goal in this section is to generate an output set that captures total volumes of GO and revenue debt issued by county and year.  We will also want the GO and RV debt issued by type of issuer, and the same breakout by purpose.  It is useful to review the table from the beginning of the Notebook here.
#
# Concept|Variable|Possible Values
# -------|--------|---------------
# Debt Type|`Security Type`| GO<br>RV
# Issuer Type|`Issuer Type Description`|District<br>City, Town Vlg<br>Local Authority<br>State Authority<br>County/Parish<br>College or Univ<br>State/Province<br>Direct<br>Indian Tribe<br>Co-op Utility
# Purpose|`Bond Buyer UOP30`|Development<br>Education<br>Electric Power<br>Environmental Facilities<br>General Purpose<br>Healthcare<br>Housing<br>Public Facilities<br>Transportation<br>Utilities
# Volume|`Amount of Maturity (M)`|Continuous
# County|`County`|Any county in the US
# State|`State`|Any state in the US
# Issue Date|`Sale Date`|Continuous (we only need the year)

# %% [markdown]
# We can read this back in here to avoid having to execute the entire Notebook.  We also no longer need FIPS components, so we can drop those.
#
# *Note:  For the time being we are dropping issues classified as `S` or `T` (as opposed to `GO` and `RV`).  We don't know what they mean currently, and there seven issues affected in the entire data set.  We can revisit this later.*

# %%
# #Read in data
# debt_fips=pd.read_csv('../data/debt_w_fips.csv',dtype={'FIPS':str})

# print debt_fips[debt_fips['Security Type'].isin(['S','T'])]

# %%
#Read in data
debt_fips=pd.read_csv('../data/debt_w_fips.csv',dtype={'FIPS':str})

#Drop unnecessary variables
for var in ['Unnamed: 0','st_cou','st_cou_g1','st_cou_final']:
    debt_fips.pop(var)
    
#Rename variables
debt_fips.columns=['Purpose','Amount','County','Issuer','Issuer_Type','State','Security_Type','Year','FIPS']

#Subset to exclude S and T Security Types
debt_fips=debt_fips[debt_fips['Security_Type'].isin(['RV','GO'])]

#Convert Amount to float
debt_fips['Amount']=debt_fips['Amount'].apply(lambda x: float(x.replace(',','')))

#Retroactively fix missing Purpose values (see validation effort below)
debt_fips.ix[426160,'Purpose']='Housing'
debt_fips.ix[328463,'Purpose']='General Purpose'
debt_fips.ix[437185,'Purpose']='General Purpose'
    
debt_fips.head()
# Out:
#            Purpose  Amount     County                          Issuer  \
# 0  General Purpose   0.076      Salem          Alloway Twp-New Jersey
# 1   Transportation   0.280       Holt          Atkinson City-Nebraska
# 2      Development   5.915   Beltrami  Bemidji Economic Dev Authority
# 3        Education   1.983     Broome         Broome Co (Johnson) CSD
# 4  General Purpose   5.666  Middlesex         Cranbury Twp-New Jersey
#
#        Issuer_Type State Security_Type  Year   FIPS
# 0   City, Town Vlg    NJ            GO  2012  34033
# 1   City, Town Vlg    NE            GO  2012  31089
# 2  Local Authority    MN            GO  2012  27007
# 3         District    NY            GO  2012  36007
# 4   City, Town Vlg    NJ            GO  2012  34023

# %%
debt_fips.ix[[426160,328463,437185]]
# Out:
#                 Purpose  Amount     County                        Issuer  \
# 426160          Housing   0.995    Oakland   Oakland Co (Lake Orion) CSD
# 328463  General Purpose  30.000  San Diego                 San Diego USD
# 437185  General Purpose   5.970     Benton  Benton Co (Kennewick) SD #17
#
#        Issuer_Type State Security_Type  Year   FIPS
# 426160    District    MI            GO  1992  26125
# 328463    District    CA            GO  1997  06073
# 437185    District    WA            GO  1992  53005

# %% [markdown]
# Our approach will be to build this up incrementally.  We will use the appropriate subsets of `debt_fips` to construct three components of the data set (by year and county):
#
# 1. Total GO and Revenue debt issue volume;
# 2. GO and Revenue debt by issuer type; and,
# 3. GO and Revenue debt by purpose.
#
# These components will then be joined together.

# %%
#Capture total debt
tot_debt=debt_fips.groupby(['Year','FIPS','Security_Type']).sum()['Amount'].unstack('Security_Type').fillna(0)

#Define function to capture aggregations by Issuer_Type and Purpose
def debt_by_concept(var):
    #Capture debt by issuer type
    tmp_debt=debt_fips.groupby(['Year','FIPS','Security_Type',var]).sum()['Amount'].sortlevel(2)
    #Unstack types
    tmp_debt=tmp_debt.unstack(['Security_Type',var])
    #Generate new column names
    new_cols=[item[0]+'_'+item[1] for item in tmp_debt.columns.values]
    #Assign new column names
    tmp_debt.columns=new_cols
    #Reorder columns, sort index, and fill in NaN values
    tmp_debt=tmp_debt[sorted(new_cols)].sortlevel(0).fillna(0)
    return tmp_debt

#Capture debt issues for Issuer Type and Purpose tabs
issuer_debt=debt_by_concept('Issuer_Type')
purpose_debt=debt_by_concept('Purpose')

#Join sets together
debt_agg=tot_debt.join([issuer_debt,purpose_debt])

debt_agg
# Out:
# Security_Type       GO       RV  GO_City, Town Vlg  GO_Co-op Utility  \
# Year FIPS
# 1984 01000       0.000  797.952              0.000                 0
#      01001       0.000    1.625              0.000                 0
#      01003       6.350   23.330              0.000                 0
#      01007       0.000    0.400              0.000                 0
#      01021       1.000    1.425              0.000                 0
#      01025       1.378    0.000              1.378                 0
#      01033       9.674    7.000              9.674                 0
#      01039       0.000    2.225              0.000                 0
#      01043       3.540    0.000              0.000                 0
#      01047       0.000   13.700              0.000                 0
#      01049       3.130   93.065              3.130                 0
#      01055       0.000    8.750              0.000                 0
#      01059       0.000    1.350              0.000                 0
#      01069      12.711    7.600             10.211                 0
#      01071       1.780    0.000              1.780                 0
#      01073      39.992  140.897             10.975                 0
#      01075       0.350    0.000              0.350                 0
#      01077       8.369    9.115              5.869                 0
#      01081       1.983   39.330              1.983                 0
#      01083       0.000    6.050              0.000                 0
#      01089       5.000    0.875              5.000                 0
#      01095       0.000    5.941              0.000                 0
#      01097      23.580  213.685              0.000                 0
#      01101      19.945   95.025             19.945                 0
#      01103       5.000    0.800              5.000                 0
#      01105       0.000   11.000              0.000                 0
#      01109       1.050    0.000              1.050                 0
#      01111       1.500    0.000              0.000                 0
#      01115       0.000    4.000              0.000                 0
#      01117       0.000  102.405              0.000                 0
# ...                ...      ...                ...               ...
# 2015 55117      19.390    5.500             16.520                 0
#      55119       2.720    0.000              2.720                 0
#      55121      41.440    0.000              4.710                 0
#      55123      20.000    0.000              0.000                 0
#      55125      18.765    0.000              0.000                 0
#      55127      99.170    0.000             15.575                 0
#      55129       3.910    0.000              0.000                 0
#      55131      35.510    0.000             19.145                 0
#      55133     257.040    0.000            118.345                 0
#      55135      11.170    0.000             11.170                 0
#      55137       3.190    0.000              1.690                 0
#      55139      47.575   60.840             38.000                 0
# ...                     ...
# 2015 55117            0.000
#      55119            0.000
#      55121            0.000
#      55123            0.000
#      55125            0.000
#      55127            0.000
#      55129            0.000
#      55131            0.000
#      55133            0.000
#      55135            0.000
#      55137            0.000
#      55139           60.680
#      55141            0.000
#      56000            0.000
#      56001            0.000
#      56005            0.000
#      56009            0.000
#      56017            0.000
#      56021            0.000
#      56025            0.000
#      56029            0.000
#      56033            0.000
#      56039            0.000
#      56041            0.000
#      56043            0.000
#      56045            0.000
#      60000            0.000
#      66000            0.000
#      72000            0.000
#      78000            0.000
#
# [61291 rows x 42 columns]

# %% [markdown]
# Perhaps we can validate these a bit by ensuring the components add up to the total debt levels for GO and RV respectively.

# %%
#Capture subsets
iss_vars={'GO':['GO_City, Town Vlg', 'GO_Co-op Utility','GO_College or Univ', 'GO_County/Parish', 'GO_Direct Issuer',\
                'GO_District', 'GO_Indian Tribe', 'GO_Local Authority','GO_State Authority', 'GO_State/Province'],
          'RV':['RV_City, Town Vlg','RV_Co-op Utility', 'RV_College or Univ', 'RV_County/Parish','RV_Direct Issuer',\
                'RV_District', 'RV_Indian Tribe','RV_Local Authority', 'RV_State Authority', 'RV_State/Province']}
pur_vars={'GO':['GO_Development', 'GO_Education', 'GO_Electric Power','GO_Environmental Facilities', 'GO_General Purpose',\
                'GO_Healthcare', 'GO_Housing', 'GO_Public Facilities','GO_Transportation', 'GO_Utilities'],
          'RV':['RV_Development','RV_Education', 'RV_Electric Power', 'RV_Environmental Facilities','RV_General Purpose',\
                'RV_Healthcare', 'RV_Housing','RV_Public Facilities', 'RV_Transportation', 'RV_Utilities']}

#Create dict to hold comparisons
component_diff={}

#For each variable group...
for i,vg in enumerate([iss_vars,pur_vars]):
    #...and for each Security Type...
    for st in ['GO','RV']:
        #...update the dict with the difference between the component and the reported sums
        component_diff.update({str(i)+'_'+st:debt_agg[st]-debt_agg[vg[st]].sum(axis=1)})

#For each comparison set...
for key in component_diff.keys():
    #...tell me the sum of the misses
    print key,'|',component_diff[key].sum()
# Out:
# 1_RV | 205.87
# 1_GO | 1.99999999999
# 0_GO | -7.65909557998e-12
# 0_RV | 1.55120916112e-11

# %% [markdown]
# What's going on with the Revenue Bonds by Purpose?  (They were originally off by \$205.87 M. GO bonds by purpose were off by \$2.0 B.)

# %%
#Capture index of problem records
idx_rv=component_diff['1_RV'][component_diff['1_RV']>1].index
idx_go=component_diff['1_GO'][component_diff['1_GO']>1].index

#Explore debt_agg at this location
print debt_agg.ix[idx_rv][['RV']+pur_vars['RV']].T
print debt_agg.ix[idx_go][['GO']+pur_vars['GO']].T
# Out:
# Year                            1999     2002
# FIPS                           12057    17089
# Security_Type
# RV                           424.470  239.895
# RV_Development                 0.000    4.000
# RV_Education                  49.405    0.000
# RV_Electric Power              4.175    6.930
# RV_Environmental Facilities  138.725    0.000
# RV_General Purpose             6.670    0.000
# RV_Healthcare                112.060    0.000
# RV_Housing                    10.915    0.000
# RV_Public Facilities          29.035    0.000
# RV_Transportation             56.560   23.470
# RV_Utilities                  12.555    3.995
# Year                           2002
# FIPS                          31153
# Security_Type
# GO                           76.650
# GO_Development                1.335
# GO_Education                 29.630
# GO_Electric Power             0.000
# GO_Environmental Facilities   2.515
# GO_General Purpose           24.245
# GO_Healthcare                 0.000
# GO_Housing                    0.000
# GO_Public Facilities          3.400
# GO_Transportation             0.000
# GO_Utilities                 13.525

# %% [markdown]
# Disparity confirmed, and the case of FIPS code 17089 in 2002, the disparity is enormous.  Perhaps the original data can shed some light?

# %%
# debt_fips[(debt_fips['Year']==2002) & (debt_fips['FIPS']=='17089')]

# %% [markdown]
# Ah, the original data lacked a purpose for a single, very large issue.  I'd wager a similar issue is occurring with FIPS code 12057 in 1999...

# %%
# debt_fips[(debt_fips['Year']==1999) & (debt_fips['FIPS']=='12057')]

# %% [markdown]
# ...and FIPS code 31153 in 2002.

# %%
# debt_fips[(debt_fips['Year']==2002) & (debt_fips['FIPS']=='31153')]

# %% [markdown]
# Inspection of the original raw data (upstream of `debt_fips`) reveals the following info about our three problematic records:
#
# `debt_fips` Index|Year|FIPS|Issuer|Amount|General Use of Proceeds|Imputed Purpose
# -----|----|----|------|------|-----------------------|----------------
# 328463|1999|12057|Covington Park Comm Dev Dt|4.37|Genl Purpose/ Public Imp|`General Purpose`
# 426160|2002|17089|Aurora Kane-DuPage Cos-Illinois|201.5|Single Family Housing|`Housing`
# 437185|2002|31153|Sarpy Co Sanit & Imp Dt #215|2.0|Genl Purpose/ Public Imp|`General Purpose`
#
# *Note: The findings of this little investigation were incorporated, retroactively, into the `debt_fips` set above.  No such issues exist any longer, which is why the prints of the problematic sections of data are commented out.*

# %%
len(debt_agg)
# Out:
# 61291

# %% [markdown]
# ## Incorporating Institutional Data

# %% [markdown]
# At this point, we are well prepared to join TEL data compiled by Dan and COSTAT/PUMS control variables of interest to our debt data.  These data were provided as SAS files.  The TEL data and COSTAT/PUMS covariate data was joined and converted to CSV in [sas2csv.ipynb](https://github.com/choct155/TELs_debt/blob/master/code/sas2csv.ipynb).  These data share merge keys (year and FIPS codes) with our debt data, which should facilitate their integration.

# %%
# !ls ../data/
# Out:
# 13slsstab1a.xls			debt_out.csv	      geocorr12.csv
# 2013_GFS_debt.xcf		debt_ts_pre_fips.csv  state_coverage.csv
# bonds.csv			debt_w_fips.csv       tel_data_alt.csv
# costat_mod_vars1940_2010.csv	fips_st_co_02_07.csv  tel_data.csv
# cty_coverage.csv		g_api_college.csv
# current_issue_geocode_list.csv	g_api_rando.csv

# %%
#Read in TEL data
tel=pd.read_csv('../../debt_data/tel_data_alt.csv',dtype={'STCOU':str})

#Rename year and FIPS columns
tel=tel.rename(columns={'YEAR':'Year',
                        'STCOU':'FIPS'})
# tel.columns=['Year','FIPS']+list(tel.columns[2:])

#Set index
tel.set_index(['Year','FIPS'],inplace=True)

#Join TEL data to debt data
debt_out=debt_agg.join(tel)

#Write to disk
debt_out.to_csv('../data/debt_out.csv')

print debt_out.ix[1990,'04001'].T.to_string()
# Out:
# Security_Type
# GO                             2.261000e+01
# RV                             0.000000e+00
# GO_City, Town Vlg              0.000000e+00
# GO_Co-op Utility               0.000000e+00
# GO_College or Univ             0.000000e+00
# GO_County/Parish               8.325000e+00
# GO_Direct Issuer               0.000000e+00
# GO_District                    1.428500e+01
# GO_Indian Tribe                0.000000e+00
# GO_Local Authority             0.000000e+00
# GO_State Authority             0.000000e+00
# GO_State/Province              0.000000e+00
# RV_City, Town Vlg              0.000000e+00
# RV_Co-op Utility               0.000000e+00
# RV_College or Univ             0.000000e+00
# RV_County/Parish               0.000000e+00
# RV_Direct Issuer               0.000000e+00
# RV_District                    0.000000e+00
# RV_Indian Tribe                0.000000e+00
# RV_Local Authority             0.000000e+00
# RV_State Authority             0.000000e+00
# RV_State/Province              0.000000e+00
# GO_Development                 0.000000e+00
# GO_Education                   1.428500e+01
# GO_Electric Power              0.000000e+00
# GO_Environmental Facilities    0.000000e+00
# GO_General Purpose             8.325000e+00
# GO_Healthcare                  0.000000e+00
# GO_Housing                     0.000000e+00
# GO_Public Facilities           0.000000e+00
# GO_Transportation              0.000000e+00
# GO_Utilities                   0.000000e+00
# RV_Development                 0.000000e+00
# RV_Education                   0.000000e+00
# RV_Electric Power              0.000000e+00
# RV_Environmental Facilities    0.000000e+00
# RV_General Purpose             0.000000e+00
# RV_Healthcare                  0.000000e+00
# RV_Housing                     0.000000e+00
# RV_Public Facilities           0.000000e+00
# RV_Transportation              0.000000e+00
# RV_Utilities                   0.000000e+00
# FIPSST                         4.000000e+00
# D_GEN_EXP                      1.340528e+05
# FOOD_SERV_EMP_PNFARM           1.552000e+03
# PRV_SCHL_KIND                  1.800000e+01
# OTH_SERV_EMP_PNFARM            1.950000e+02
# PRE_1940                       1.453000e+03
# MED_INC                        2.017300e+04
# PERS_POVT                      3.940000e+01
# PRV_SCHL_9_12                  2.520000e+02
# PC_GEN_EXP                     2.189600e+03
# MANU_EMP_PNFARM                3.230000e+02
# HSG_UNITS                      2.673100e+04
# PUB_SCHL_OV3_M                 1.063900e+04
# LANDAREA                       1.121105e+04
# POP_OV65                       5.787000e+03
# PRV_SCHL_9_12_F                1.890000e+02
# TAX_REV                        2.553620e+04
# PRV_SCHL_ELEM_HS               6.190000e+02
# PUB_SCHL_ELEM_HS               1.937200e+04
# RES_POP1                       6.109360e+04
# PUB_SCHL_OV3_F                 1.110600e+04
# PRV_SCHL_PREK_F                0.000000e+00
# RETL_EMP_PNFARM                1.197000e+03
# CH_HS_UNT                      4.160000e+01
# PROF_SERV_EMP_PNFARM           1.710000e+02
# MFG_EMP                        0.000000e+00
# PRV_SCHL_KIND_M                1.100000e+01
# PRV_SCHL_PREK_M                6.400000e+01
# SUPP_SERV_EMP_PNFARM           1.330000e+02
# POP_TH18                       2.667200e+04
# POV_EST_FAM_NUMER              5.468000e+03
# GEN_REV                        1.226712e+05
# EDUC_SERV_EMP_PNFARM           4.600000e+02
# SS_PMT                         2.169000e+03
# PRV_SCHL_PREK                  1.550000e+02
# PT_REV                         2.252200e+04
# PRV_SCHL_KIND_F                7.300000e+01
# PRV_SCHL_1_8                   3.670000e+02
# PRV_SCHL_5_8_M                 3.080000e+02
# VACANT                         1.804000e+03
# PUB_SCHL_TOT                   1.395600e+04
# PRV_SCHL_1_4_M                 3.700000e+01
# TOT_EMP                        2.464300e+04
# HSG_UNITS_ACS                  2.673100e+04
# MDHOMEVAL                      4.170000e+04
# TOT_AREA                       1.121917e+04
# POV_EST_FAM_DENOM              1.326000e+04
# PUB_SCHL_OV3                   2.588500e+04
# SS_PERS                        6.095000e+03
# PC_INC                         1.543600e+04
# RES_POP2                       6.951600e+04
# PRV_SCHL_9_12_M                7.900000e+01
# HSLD_PERS                      3.800000e+00
# PRV_SCHL_1_4_F                 1.320000e+02
# PRV_SCHL_5_8_F                 1.990000e+02
# TOT_EMP_PNFARM                 6.226000e+03
# RETL_EMP                       1.899000e+03
# IGR_ST                         5.447260e+04
# RESPOP                         6.109360e+04
# PRV_SCHL                       7.920000e+02
# DENSITY                        5.449409e+00
# POPGROWTH                      1.606921e-02
# PYOUNG                         4.365760e-01
# POP65                          9.472351e-02
# RESPOP2                        3.732428e+09
# PRE1940                        5.435637e-02
# PVT_SCH                        3.059687e-02
# POVERTY                        4.123680e-01
# PC_SSI                         3.558655e-01
# DIVERSITY                      3.743258e+04
# EMP_RES                        1.019092e-01
# MANU_RES                       5.286970e-03
# RETL_RES                       1.959289e-02
# SERV_RES                       4.110087e-02
# FIPST_N                        4.000000e+00
# RATE_L                         1.000000e+00
# RATE_L2                        0.000000e+00
# MRATE_L                        0.000000e+00
# CRATE_L                        0.000000e+00
# SRATE_L                        0.000000e+00
# SRATE_L2                       0.000000e+00
# MRATE_L2                       0.000000e+00
# CRATE_L2                       0.000000e+00
# MLEVY_L                        1.000000e+00
# CLEVY_L                        1.000000e+00
# CLEVY_L2                       0.000000e+00
# MLEVY_L2                       0.000000e+00
# MLEVY_L3                       0.000000e+00
# SLEVY_L                        0.000000e+00
# CLEVY_L3                       0.000000e+00
# CLEVY_L4                       0.000000e+00
# MLEVY_L4                       0.000000e+00
# SLEVY_L2                       0.000000e+00
# SLEVY_L3                       0.000000e+00
# SLEVY_L4                       0.000000e+00
# ASMT_L                         1.000000e+00
# ASMT_L2                        0.000000e+00
# ASMT_L3                        0.000000e+00
# CREVU_L                        0.000000e+00
# MREVU_L                        0.000000e+00
# SREVU_L                        0.000000e+00
# CGEXP_L                        1.000000e+00
# MGEXP_L                        1.000000e+00
# SGEXP_L                        1.000000e+00
# SGEXP_L2                       0.000000e+00
# MGEXP_L2                       0.000000e+00
# CFDISC_L                       0.000000e+00
# MFDISC_L                       0.000000e+00
# SFDISC_L                       0.000000e+00
# HOME_STEAD                     1.000000e+00
# HOME_STEAD2                    0.000000e+00
# HOME_STEAD3                    0.000000e+00
# CB_E                           1.000000e+00
# CB_G                           0.000000e+00
# CB_G2                          0.000000e+00
# CB_E2                          0.000000e+00
# CB_E3                          0.000000e+00
# CB_E4                          0.000000e+00
# FFDISC_L                       0.000000e+00
# TYPE1                          0.000000e+00
# TYPE2                          1.000000e+00
# BOTH                           0.000000e+00
# LIMITS                         1.000000e+00
# TYPE2_Y                        1.700000e+01
# SPC_RATE                       0.000000e+00
# LEVY_L                         1.000000e+00
# REVU_L                         0.000000e+00
# GEXP_L                         1.000000e+00
# GP_RATE                        0.000000e+00
# GP_LEVY                        1.000000e+00
# GP_REVU                        0.000000e+00
# GP_GEXP                        1.000000e+00
# GP_LMT                         1.000000e+00
# SC_LMT                         1.000000e+00
# TREND                          2.100000e+01

# %% [markdown]
# It should be noted that the `tel` data is really the integration of two input sets, so `debt_out` is a three-part join.  This has implications for our data universe.  Each set has a different number of counties, and these sets do not necessarily overlap completely.  In the **Data Checks** section of *sas2csv*, we captured the disparity in state coverage in a data set, and wrote it to disk as `cty_coverage.csv` (which we are ultimately concerned with).  Note that in the case of the join in *sas2csv*, we were joining a state level data set (TEL data) to county level data (COSTATS/PUMS).  Therefore, for each state covered in the TEL data, all counties are included by construction.
#
# We can now take the opportunity to check the year-county overlap between the `tel` and `debt_agg` sets.

# %%
#Capture union of indices
u_idx=list(set(tel.index.values).union(set(debt_agg.index.values)))

#Generate county coverage dict
cty_cov=DataFrame({'tel':[idx in tel.index for idx in u_idx],
                   'debt_agg':[idx in debt_agg.index for idx in u_idx]},
                    index=pd.MultiIndex.from_tuples(u_idx,names=['Year','FIPS'])).sortlevel(0)

print 'Number of year-counties represented in the TEL set:',cty_cov['tel'].sum()
print 'Number of year-counties represented in the aggregate debt set:',cty_cov['debt_agg'].sum()
print 'Number of complete cases:',len(cty_cov[(cty_cov==True).all(axis=1)])

#Write to disk
cty_cov.to_csv('../data/cty_coverage.csv')

cty_cov.ix[1990:]
# Out:
# Number of year-counties represented in the TEL set: 127405
# Number of year-counties represented in the aggregate debt set: 61291
# Number of complete cases: 51501
#            debt_agg    tel
# Year FIPS
# 1990 00000    False   True
#      01000     True   True
#      01001     True   True
#      01003     True   True
#      01005     True   True
#      01007    False   True
#      01009    False   True
#      01011     True   True
#      01013    False   True
#      01015     True   True
#      01017     True   True
#      01019    False   True
#      01021     True   True
#      01023    False   True
#      01025     True   True
#      01027    False   True
#      01029    False   True
#      01031     True   True
#      01033     True   True
#      01035     True   True
#      01037    False   True
#      01039    False   True
#      01041    False   True
#      01043     True   True
#      01045    False   True
#      01047     True   True
#      01049     True   True
#      01051    False   True
#      01053    False   True
#      01055     True   True
# ...             ...    ...
# 2015 55117     True  False
#      55119     True  False
#      55121     True  False
#      55123     True  False
#      55125     True  False
#      55127     True  False
#      55129     True  False
#      55131     True  False
#      55133     True  False
#      55135     True  False
#      55137     True  False
#      55139     True  False
#      55141     True  False
#      56000     True  False
#      56001     True  False
#      56005     True  False
#      56009     True  False
#      56017     True  False
#      56021     True  False
#      56025     True  False
#      56029     True  False
#      56033     True  False
#      56039     True  False
#      56041     True  False
#      56043     True  False
#      56045     True  False
#      60000     True  False
#      66000     True  False
#      72000     True  False
#      78000     True  False
#
# [76796 rows x 2 columns]
