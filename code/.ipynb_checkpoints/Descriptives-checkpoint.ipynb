# %% [markdown]
# This is the notebook to establish the data required to create descriptive statistics of the debt data. Essentially this data will be used to tell the narrative of the story. To be useful the data will need to be deflated and then expressed in percapita terms. It will liklely need to be aggregated at the state, region, and national level with the debt separated by general obligation and revenue bonds.

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import glob
import requests

# %% [markdown]
# # Import State and Local Price deflators

# %% [markdown]
# State and local price deflators were downloaded [here](https://research.stlouisfed.org/fred2/series/A829RD3A086NBEA#)

# %%
defl = pd.read_excel('../data/state_local_deflators.xls', header=10 )

# %%
defl.rename(columns={'A829RD3A086NBEA': 'SLDefl'}, inplace=True)

# %%
defl.head()
# Out:
#   observation_date  SLDefl
# 0       1929-01-01   3.968
# 1       1930-01-01   3.862
# 2       1931-01-01   3.632
# 3       1932-01-01   3.258
# 4       1933-01-01   3.372

# %%
defl['yr'] = defl.observation_date.map(lambda x: x.strftime('%Y'))

# %%
defl.drop('observation_date', inplace=True, axis = 1)

# %% [markdown]
# Now I need to convert the index into a multiplier. Since 2009 is the base year, we need the value for 2009.

# %%
defl.loc[defl['yr']=='2009']
# Out:
#     SLDefl    yr
# 80     100  2009

# %% [markdown]
# The formula for the index will be Base/Comparison

# %%
defl['index'] = 100/defl['SLDefl']

# %%
defl.head()
# Out:
#    SLDefl    yr      index
# 0   3.968  1929  25.201613
# 1   3.862  1930  25.893320
# 2   3.632  1931  27.533040
# 3   3.258  1932  30.693677
# 4   3.372  1933  29.655991

# %% [markdown]
# Now I need to import the personal income and population data from [here](http://www.bea.gov/regional/downloadzip.cfm)

# %%
inc = pd.read_csv('../data/SA1_1929_2014.csv')

# %%
inc['GeoFIPS'] = inc['GeoFIPS'].apply(lambda x: x.zfill(5))

inc['ST']= inc['GeoFIPS'].str.extract('(..)')

# %%
inc.head()
# Out:
#   GeoFIPS        GeoName  Region Table  LineCode IndustryClassification  \
# 0   00000  United States     NaN   SA1         1                    ...
# 1   00000  United States     NaN   SA1         2                    ...
# 2   00000  United States     NaN   SA1         3                    ...
# 3   01000        Alabama       5   SA1         1                    ...
# 4   01000        Alabama       5   SA1         2                    ...
#
#                                Description       1929       1930       1931  \
# 0   Personal income (thousands of dollars)   85126000   76371000   65507000
# 1                  Population (persons) 1/  121769000  123075000  124038000
# 2  Per capita personal income (dollars) 2/        699        621        528
# 3   Personal income (thousands of dollars)     842894     697154     583342
# 4                  Population (persons) 1/    2644000    2647000    2649000
#
#   ...         2006         2007         2008         2009         2010  \
# 0 ...  11381350000  11995419000  12492705000  12079444000  12459613000
# 1 ...    298379912    301231207    304093966    306771529    309347057
# 2 ...        38144        39821        41082        39376        40277
# 3 ...    146661249    153787754    159993535    157141435    163066901
# 4 ...      4628981      4672840      4718206      4757938      4785822
#
#           2011         2012         2013         2014  ST
# 0  13233436000  13904485000  14064468000  14683147000  00
# 1    311721632    314112078    316497531    318857056  00
# 2        42453        44266        44438        46049  00
# 3    169030399    173601429    174876574    181908767  01
# 4      4801695      4817484      4833996      4849377  01
#
# [5 rows x 94 columns]

# %% [markdown]
# 1 - Personal Income
# 2 - Population
# 3 - Per Capita Personal Income

# %%
droplist = (['Table','GeoName','Description','IndustryClassification'])

inc.drop(droplist, inplace = True, axis = 1)

# %% [markdown]
# This will drop the notes in the dataframe, as well as the unnecessary years

# %%
inc = inc.drop(inc.index[[180,181,182,183]])

# %%
inc.drop(['1929', '1930','1931','1932','1933','1934','1935','1936','1937','1938','1939','1940',\
            '1941','1942','1943','1944','1945','1946','1947','1948','1949','1950','1951','1952',\
            '1953','1954','1955','1956','1957','1958','1959','1960','1961','1962','1963','1964',\
            '1965','1966','1967','1968','1969','1970','1971','1972','1973','1974','1975','1976',\
            '1977','1978','1979','1980','1981','1982','1983'], axis = 1, inplace = True)

# %%
perinc = inc[inc['LineCode']==1]
perpop = inc[inc['LineCode']==2]
perpopinc = inc[inc['LineCode']==3]

# %%
perinc.drop(['LineCode', 'GeoFIPS'], inplace = True, axis = 1)
perpop.drop(['LineCode', 'GeoFIPS'], inplace = True, axis = 1)
perpopinc.drop(['LineCode', 'GeoFIPS'], inplace = True, axis = 1)
# Out:
# /Users/chadsmith/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/chadsmith/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from IPython.kernel.zmq import kernelapp as app
# /Users/chadsmith/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %% [markdown]
# I need to transpose this so that each year is a row. This is tricky because groupby, stack, and pivot all either change the index or make vital columns unusable. **Melt, is the right tool here. That only cost me a day and my sanity...**

# %%
perpop = pd.melt(perpop, id_vars=['ST','Region'])
perpop.rename(columns={'variable':'Year', 'value':'population'},inplace=True)

# %%
perinc.head()
# Out:
#     Region        1984        1985        1986        1987        1988  \
# 0      NaN  3268535000  3501927000  3712243000  3940859000  4260753000
# 3        5    42649118    45942335    48627446    51486400    55388090
# 6        8     9961459    10772149    10868683    10430514    10875485
# 9        6    39699293    44054015    48294793    52226134    56265019
# 12       5    24474975    26082631    27399821    28476005    30546100
#
#           1989        1990        1991        1992 ...         2006  \
# 0   4603969000  4890453000  5055766000  5402109000 ...  11381350000
# 3     60312581    64070364    67662101    72847428 ...    146661249
# 6     11938954    12650093    13199663    14093288 ...     27380164
# 9     60486975    63383028    66575466    70987974 ...    210103296
# 12    32776869    34487482    36434402    39744696 ...     83182071
#
#            2007         2008         2009         2010         2011  \
# 0   11995419000  12492705000  12079444000  12459613000  13233436000
# 3     153787754    159993535    157141435    163066901    169030399
# 6      29516606     32496796     32283659     34103385     36527487
# 9     221596785    226573627    216064765    219195775    230920326
# 12     88819878     93232570     91625136     93486029     99791639
#
#            2012         2013         2014  ST
# 0   13904485000  14064468000  14683147000  00
# 3     173601429    174876574    181908767  01
# 6      38213009     37791031     39792685  02
# 9     241192186    243656863    255092928  04
# 12    107032727    108080656    112076107  05
#
# [5 rows x 33 columns]

# %%
perpopinc = pd.melt(perpopinc, id_vars=['ST','Region'])
perpopinc.rename(columns={'variable':'Year', 'value':'per_cap_person_income'}, inplace=True)

# %%
perinc = pd.melt(perinc, id_vars=['ST','Region'])
perinc.rename(columns={'variable':'Year', 'value':'person_income'}, inplace=True)

# %%
perpopinc.head()
# Out:
#    ST  Region  Year  per_cap_person_income
# 0  00     NaN  1984                  13860
# 1  01       5  1984                  10792
# 2  02       8  1984                  19391
# 3  04       6  1984                  12943
# 4  05       5  1984                  10551

# %% [markdown]
# Now we can merge these back into one file

# %%
inc = pd.merge(perinc, perpop, left_on=['ST','Region','Year'], right_on=['ST','Region','Year'])

# %%
inc = pd.merge(inc, perpopinc, left_on=['ST','Region','Year'], right_on=['ST','Region','Year'])

# %%
inc.head()
# Out:
#    ST  Region  Year  person_income  population  per_cap_person_income
# 0  00     NaN  1984     3268535000   235824907                  13860
# 1  01       5  1984       42649118     3951824                  10792
# 2  02       8  1984        9961459      513704                  19391
# 3  04       6  1984       39699293     3067134                  12943
# 4  05       5  1984       24474975     2319767                  10551

# %%
df = pd.read_csv('../data/debt_out.csv')

# %% [markdown]
# This is the list of variables (largly costats) that are not required for this analysis

# %%
df = df[['Year','FIPS','GO','RV','GO_City, Town Vlg','GO_Co-op Utility',\
        'GO_College or Univ','GO_County/Parish','GO_Direct Issuer','GO_District',\
        'GO_Indian Tribe','GO_Local Authority','GO_State Authority','GO_State/Province',\
        'RV_City, Town Vlg','RV_Co-op Utility','RV_College or Univ','RV_County/Parish',\
        'RV_Direct Issuer','RV_District','RV_Indian Tribe','RV_Local Authority','RV_State Authority',\
        'RV_State/Province','GO_Development','GO_Education','GO_Electric Power','GO_Environmental Facilities',\
        'GO_General Purpose','GO_Healthcare','GO_Housing','GO_Public Facilities','GO_Transportation',\
        'GO_Utilities','RV_Development','RV_Education','RV_Electric Power','RV_Environmental Facilities',\
        'RV_General Purpose','RV_Healthcare','RV_Housing','RV_Public Facilities','RV_Transportation',\
        'RV_Utilities']]

# %%
df.head()
# Out:
#    Year  FIPS    GO       RV  GO_City, Town Vlg  GO_Co-op Utility  \
# 0  1984  1000  0.00  797.952                  0                 0
# 1  1984  1001  0.00    1.625                  0                 0
# 2  1984  1003  6.35   23.330                  0                 0
# 3  1984  1007  0.00    0.400                  0                 0
# 4  1984  1021  1.00    1.425                  0                 0
#
#    GO_College or Univ  GO_County/Parish  GO_Direct Issuer  GO_District  \
# 0                   0              0.00                 0            0
# 1                   0              0.00                 0            0
# 2                   0              6.35                 0            0
# 3                   0              0.00                 0            0
# 4                   0              1.00                 0            0
#
#        ...       RV_Development  RV_Education  RV_Electric Power  \
# 0      ...                  6.0             0              0.000
# 1      ...                  0.0             0              0.000
# 2      ...                  1.9            12              6.395
# 3      ...                  0.4             0              0.000
# 4      ...                  0.0             0              0.000
#
#    RV_Environmental Facilities  RV_General Purpose  RV_Healthcare  RV_Housing  \
# 0                            0               0.000         259.12     123.722
# 1                            0               0.000           0.00       0.000
# 2                            0               0.000           0.00       0.000
# 3                            0               0.000           0.00       0.000
# 4                            0               1.425           0.00       0.000
#
#    RV_Public Facilities  RV_Transportation  RV_Utilities
# 0                     0             409.11         0.000
# 1                     0               0.00         1.625
# 2                     0               0.00         3.035
# 3                     0               0.00         0.000
# 4                     0               0.00         0.000
#
# [5 rows x 44 columns]

# %%
df['FIPS']=df.FIPS.astype('str')
df['Year']=df.Year.astype('str')

# %%
df['FIPS'] = df['FIPS'].apply(lambda x: x.zfill(5))

# %% [markdown]
# This establishes the list of dollar values that need to be deflated

# %%
dollar_list =(['GO','RV','GO_City, Town Vlg','GO_Co-op Utility',\
               'GO_College or Univ','GO_County/Parish','GO_Direct Issuer',\
               'GO_District','GO_Indian Tribe','GO_Local Authority',\
               'GO_State Authority','GO_State/Province','RV_City, Town Vlg',\
               'RV_Co-op Utility','RV_College or Univ','RV_County/Parish',\
               'RV_Direct Issuer','RV_District','RV_Indian Tribe','RV_Local Authority',\
               'RV_State Authority','RV_State/Province','GO_Development','GO_Education',\
               'GO_Electric Power','GO_Environmental Facilities','GO_General Purpose',\
               'GO_Healthcare','GO_Housing','GO_Public Facilities','GO_Transportation',\
               'GO_Utilities','RV_Development','RV_Education','RV_Electric Power',\
               'RV_Environmental Facilities','RV_General Purpose','RV_Healthcare',\
               'RV_Housing','RV_Public Facilities','RV_Transportation','RV_Utilities'])

# %%
defl.drop('SLDefl', inplace = True, axis = 1)

# %%
defl.head()
# Out:
#      yr      index
# 0  1929  25.201613
# 1  1930  25.893320
# 2  1931  27.533040
# 3  1932  30.693677
# 4  1933  29.655991

# %%
df = pd.merge(defl, df, left_on = 'yr', right_on = 'Year', how = 'right')

# %% [markdown]
# This will deflate the $$$'s'

# %%
for i in dollar_list:
    df[i] = df[i] * df['index']

# %% [markdown]
# I think it is best to break the FIPS into the first two digits which is the state

# %%
df['ST']= df['FIPS'].str.extract('(..)')

# %%
df.drop(['yr','index'], inplace = True, axis = 1)

# %%
df.head()
# Out:
#    Year   FIPS         GO           RV  GO_City, Town Vlg  GO_Co-op Utility  \
# 0  1984  01000   0.000000  1927.094453                  0                 0
# 1  1984  01001   0.000000     3.924457                  0                 0
# 2  1984  01003  15.335571    56.343130                  0                 0
# 3  1984  01007   0.000000     0.966020                  0                 0
# 4  1984  01021   2.415051     3.441447                  0                 0
#
#    GO_College or Univ  GO_County/Parish  GO_Direct Issuer  GO_District ...  \
# 0                   0          0.000000                 0            0 ...
# 1                   0          0.000000                 0            0 ...
# 2                   0         15.335571                 0            0 ...
# 3                   0          0.000000                 0            0 ...
# 4                   0          2.415051                 0            0 ...
#
#    RV_Education  RV_Electric Power  RV_Environmental Facilities  \
# 0      0.000000           0.000000                            0
# 1      0.000000           0.000000                            0
# 2     28.980607          15.444249                            0
# 3      0.000000           0.000000                            0
# 4      0.000000           0.000000                            0
#
#    RV_General Purpose  RV_Healthcare  RV_Housing  RV_Public Facilities  \
# 0            0.000000      625.78791   298.79489                     0
# 1            0.000000        0.00000     0.00000                     0
# 2            0.000000        0.00000     0.00000                     0
# 3            0.000000        0.00000     0.00000                     0
# 4            3.441447        0.00000     0.00000                     0
#
#    RV_Transportation  RV_Utilities  ST
# 0         988.021349      0.000000  01
# 1           0.000000      3.924457  01
# 2           0.000000      7.329679  01
# 3           0.000000      0.000000  01
# 4           0.000000      0.000000  01
#
# [5 rows x 45 columns]

# %%
state_agg = df.groupby(['Year', 'ST']).sum()

# %%
state_agg.head()
# Out:
#                   GO            RV  GO_City, Town Vlg  GO_Co-op Utility  \
# Year ST
# 1984 01   371.058034   3904.337431         202.035888                 0
#      02    79.769121    675.042867          40.246818                 0
#      04   972.224503   2282.556090         293.945468                 0
#      05    35.027894    394.870433           7.245152                 0
#      06  8639.488492  17662.146497         747.347067                 0
#
#          GO_College or Univ  GO_County/Parish  GO_Direct Issuer  GO_District  \
# Year ST
# 1984 01                   0        162.984520                 0     6.037626
#      02                   0          0.000000                 0     0.000000
#      04                   0        123.397010                 0   554.882025
#      05                   0          0.000000                 0    27.782742
#      06                   0       1991.689811                 0  1328.548313
#
#          GO_Indian Tribe  GO_Local Authority      ...       RV_Development  \
# Year ST                                           ...
# 1984 01                0             0.00000      ...           303.970343
#      02                0             0.00000      ...            54.978627
#      04                0             0.00000      ...           327.565387
#      05                0             0.00000      ...            67.923298
#      06                0           780.18934      ...          1427.657159
#
#          RV_Education  RV_Electric Power  RV_Environmental Facilities  \
# Year ST
# 1984 01     63.902239          28.847779                   897.287898
#      02     14.490304           0.000000                     0.000000
#      04     72.705098          63.056971                   549.448161
#      05     23.447726           0.000000                    77.643877
#      06   1217.103388        2038.242326                  1303.173376
#
#          RV_General Purpose  RV_Healthcare   RV_Housing  RV_Public Facilities  \
# Year ST
# 1984 01           12.075253     788.282175   391.955466             51.773855
#      02            0.000000       0.000000   605.573937              0.000000
#      04          169.232255     349.083488   326.210544             16.398194
#      05            0.000000      51.017944   125.039245              9.660202
#      06         2703.134736    1297.155070  4311.973821            570.302123
#
#          RV_Transportation  RV_Utilities
# Year ST
# 1984 01        1013.560509    352.681914
#      02           0.000000      0.000000
#      04         223.597459    185.258531
#      05          16.905354     23.232787
#      06        1621.805492   1171.599005
#
# [5 rows x 42 columns]

# %%
state_agg = state_agg.reset_index()

# %%
inc.head()
# Out:
#    ST  Region  Year  person_income  population  per_cap_person_income
# 0  00     NaN  1984     3268535000   235824907                  13860
# 1  01       5  1984       42649118     3951824                  10792
# 2  02       8  1984        9961459      513704                  19391
# 3  04       6  1984       39699293     3067134                  12943
# 4  05       5  1984       24474975     2319767                  10551

# %%
closing_in=pd.merge(state_agg, inc, left_on=['Year', 'ST'], right_on=['Year', 'ST'])

# %% [markdown]
# **FINALLY**
#
# That took much longer than it should. Since debt os expressed in millions, I now need to multiply all dollar amounts so that they are in actual millions before dividing them into the different terms. I think the most efficient way to do this is to create another function using the 'dollar_list' that was previously established.

# %%
for i in dollar_list:
    closing_in[i] = closing_in[i] * 1000000
    closing_in[i +'_percapita']= closing_in[i]/closing_in['population']

# %%
closing_in.head()
# Out:
#    Year  ST            GO            RV  GO_City, Town Vlg  GO_Co-op Utility  \
# 0  1984  01  3.710580e+08  3.904337e+09       2.020359e+08                 0
# 1  1984  02  7.976912e+07  6.750429e+08       4.024682e+07                 0
# 2  1984  04  9.722245e+08  2.282556e+09       2.939455e+08                 0
# 3  1984  05  3.502789e+07  3.948704e+08       7.245152e+06                 0
# 4  1984  06  8.639488e+09  1.766215e+10       7.473471e+08                 0
#
#    GO_College or Univ  GO_County/Parish  GO_Direct Issuer   GO_District  \
# 0                   0      1.629845e+08                 0  6.037626e+06
# 1                   0      0.000000e+00                 0  0.000000e+00
# 2                   0      1.233970e+08                 0  5.548820e+08
# 3                   0      0.000000e+00                 0  2.778274e+07
# 4                   0      1.991690e+09                 0  1.328548e+09
#
#             ...            RV_Development_percapita  RV_Education_percapita  \
# 0           ...                           76.918998               16.170315
# 1           ...                          107.023941               28.207496
# 2           ...                          106.798525               23.704572
# 3           ...                           29.280224               10.107794
# 4           ...                           55.240490               47.093511
#
#    RV_Electric Power_percapita  RV_Environmental Facilities_percapita  \
# 0                     7.299864                             227.056645
# 1                     0.000000                               0.000000
# 2                    20.558923                             179.140579
# 3                     0.000000                              33.470550
# 4                    78.865927                              50.423826
#
#    RV_General Purpose_percapita  RV_Healthcare_percapita  \
# 0                      3.055615               199.472996
# 1                      0.000000                 0.000000
# 2                     55.176023               113.814228
# 3                      0.000000                21.992702
# 4                    104.592680                50.190959
#
#    RV_Housing_percapita  RV_Public Facilities_percapita  \
# 0             99.183432                       13.101255
# 1           1178.838274                        0.000000
# 2            106.356796                        5.346422
# 3             53.901640                        4.164299
# 4            166.843661                       22.066761
#
#    RV_Transportation_percapita  RV_Utilities_percapita
# 0                   256.479162               89.245349
# 1                     0.000000                0.000000
# 2                    72.901106               60.401186
# 3                     7.287522               10.015138
# 4                    62.752692               45.332805
#
# [5 rows x 90 columns]

# %% [markdown]
# We will be using the BEA region definitions that are found [here](http://www.bea.gov/regional/docs/regions.cfm). This file was added to the data file and labeled region.

# %%
regions = pd.read_csv('../data/regions.csv')

# %%
regions.head()
# Out:
#    State or Region code State or Region name Abbreviation  Region code
# 0                    91   New England Region         NENG            1
# 1                    92       Mideast Region         MEST            2
# 2                    93   Great Lakes Region         GLAK            3
# 3                    94        Plains Region         PLNS            4
# 4                    95     Southeast Region         SEST            5

# %%
droplist = (['State or Region code','Abbreviation'])
regions.drop(droplist, inplace=True, axis=1)

# %%
closing_in = pd.merge(closing_in, regions, left_on='Region', right_on='Region code')

# %%
closing_in.head()
# Out:
#    Year  ST            GO            RV  GO_City, Town Vlg  GO_Co-op Utility  \
# 0  1984  01  3.710580e+08  3.904337e+09       2.020359e+08                 0
# 1  1984  05  3.502789e+07  3.948704e+08       7.245152e+06                 0
# 2  1984  12  1.212459e+09  1.136413e+10       2.251528e+08                 0
# 3  1984  13  7.588089e+08  3.849458e+09       3.282054e+07                 0
# 4  1984  21  1.613254e+08  2.635192e+09       1.229261e+07                 0
#
#    GO_College or Univ  GO_County/Parish  GO_Direct Issuer   GO_District  \
# 0                   0      1.629845e+08                 0  6.037626e+06
# 1                   0      0.000000e+00                 0  2.778274e+07
# 2                   0      2.877533e+08                 0  5.036322e+08
# 3                   0      6.264641e+07                 0  1.378752e+08
# 4                   0      0.000000e+00                 0  1.490328e+08
#
#       ...       RV_Electric Power_percapita  \
# 0     ...                          7.299864
# 1     ...                          0.000000
# 2     ...                        268.307162
# 3     ...                         39.088193
# 4     ...                          6.026747
#
#    RV_Environmental Facilities_percapita  RV_General Purpose_percapita  \
# 0                             227.056645                      3.055615
# 1                              33.470550                      0.000000
# 2                             257.588553                     24.167077
# 3                             361.040139                      5.198101
# 4                             159.425823                      4.747811
#
#    RV_Healthcare_percapita  RV_Housing_percapita  \
# 0               199.472996             99.183432
# 1                21.992702             53.901640
# 2               149.411489            131.348363
# 3                24.552220            111.907957
# 4                78.003961             86.579430
#
#    RV_Public Facilities_percapita  RV_Transportation_percapita  \
# 0                       13.101255                   256.479162
# 1                        4.164299                     7.287522
# 2                       29.582164                    69.811624
# 3                        2.692383                     1.034736
# 4                       63.665766                   211.975241
#
#    RV_Utilities_percapita  State or Region name  Region code
# 0               89.245349      Southeast Region            5
# 1               10.015138      Southeast Region            5
# 2               86.549964      Southeast Region            5
# 3               52.203681      Southeast Region            5
# 4               29.346245      Southeast Region            5
#
# [5 rows x 92 columns]

# %% [markdown]
# #Lets Ship IT

# %%
closing_in.to_csv('../data/Descriptives.csv')
