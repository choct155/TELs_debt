# %% [markdown]
# # Estimating the Likelihood of Debt Issue

# %% [markdown]
# As a complement to the panel models in *Debt_on_TEL*, this Notebook renders debt issues into a discrete variable.  If debt issues occur (`TOT_DEBT > 1`), it scored as one (zero otherwise).

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %% [markdown]
# ## Data Input

# %% [markdown]
# We will use the same data set that has been used in *Debt_on_TEL*.

# %%
#Read in data
data=pd.read_csv('../data/debt_mod.csv')

#Generate new binary indicator of debt issue
data['BIN_DEBT_ISSUE']=np.where(data['TOT_DEBT']>0,1,0)

data['BIN_DEBT_ISSUE'].describe()
# Out:
# count    21816.000000
# mean         0.888797
# std          0.314390
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: BIN_DEBT_ISSUE, dtype: float64

# %% [markdown]
# ## Logistic Model Design

# %% [markdown]
# We have three specifications we will be estimating, based upon three sets of TEL measures.

# %%
#Define specifications
spc1='BIN_DEBT_ISSUE~TYPE1+TYPE2+TYPE2_Y+RESPOP+RESPOP2+DENSITY+POPGROWTH+HSLD_PERS+PRE1940+PYOUNG+'+\
     'PVT_SCH+POP65+PC_INC+POVERTY+PC_SSI+DIVERSITY+EMP_RES+MANU_RES+RETL_RES+SERV_RES+BIN_REC+'+\
     'OSRC_GAP+REAL_RATE+R_CTY_INT_DIFF+GEN_REV+TAX_EFFORT+IGR_ST+REAL_RATE_CHANGE+TOT_DEBT_OUTST+C(FIPSST)'
spc2='BIN_DEBT_ISSUE~LIMITS+BOTH+RESPOP+RESPOP2+DENSITY+POPGROWTH+HSLD_PERS+PRE1940+PYOUNG+'+\
     'PVT_SCH+POP65+PC_INC+POVERTY+PC_SSI+DIVERSITY+EMP_RES+MANU_RES+RETL_RES+SERV_RES+BIN_REC+'+\
     'OSRC_GAP+REAL_RATE+R_CTY_INT_DIFF+GEN_REV+TAX_EFFORT+IGR_ST+REAL_RATE_CHANGE+TOT_DEBT_OUTST+C(FIPSST)'
spc3='BIN_DEBT_ISSUE~RATE_L+ASMT_L+GP_LMT+SC_LMT+RESPOP+RESPOP2+DENSITY+POPGROWTH+HSLD_PERS+PRE1940+PYOUNG+'+\
     'PVT_SCH+POP65+PC_INC+POVERTY+PC_SSI+DIVERSITY+EMP_RES+MANU_RES+RETL_RES+SERV_RES+BIN_REC+'+\
     'OSRC_GAP+REAL_RATE+R_CTY_INT_DIFF+GEN_REV+TAX_EFFORT+IGR_ST+REAL_RATE_CHANGE+TOT_DEBT_OUTST+C(FIPSST)'
        
#Capture in dict
spec_dict={1:spc1,
           2:spc2,
           3:spc3}

# %% [markdown]
# We can capture the results from these specs in another dict.

# %%
mod_dict={1:smf.glm(formula=spec_dict[1],data=data,family=sm.families.Binomial()).fit(),
          2:smf.glm(formula=spec_dict[2],data=data,family=sm.families.Binomial()).fit(),
          3:smf.glm(formula=spec_dict[3],data=data,family=sm.families.Binomial()).fit()}

# %%
mod_dict[1].summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:         BIN_DEBT_ISSUE   No. Observations:                21816
# Model:                            GLM   Df Residuals:                    21808
# Model Family:                Binomial   Df Model:                            7
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -6944.5
# Date:                Sun, 15 Nov 2015   Deviance:                       13889.
# Time:                        18:32:11   Pearson chi2:                 1.93e+04
# No. Iterations:                   100
# ====================================================================================
#                        coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# Intercept            6.3610      0.634     10.032      0.000         5.118     7.604
# C(FIPSST)[T.4]      -1.2077      0.348     -3.472      0.001        -1.889    -0.526
# C(FIPSST)[T.5]       0.1317      0.236      0.557      0.577        -0.332     0.595
# C(FIPSST)[T.6]      -0.5299      0.277     -1.911      0.056        -1.073     0.013
# C(FIPSST)[T.8]      -1.0690      0.308     -3.467      0.001        -1.673    -0.465
# C(FIPSST)[T.9]       0.8698      0.341      2.547      0.011         0.201     1.539
# C(FIPSST)[T.10]      0.1036      0.418      0.248      0.804        -0.717     0.924
# C(FIPSST)[T.12]     -0.3190      0.221     -1.441      0.150        -0.753     0.115
# C(FIPSST)[T.13]      0.4761      0.221      2.153      0.031         0.043     0.910
# C(FIPSST)[T.15]      0.1506      0.549      0.274      0.784        -0.925     1.227
# C(FIPSST)[T.16]     -0.7054      0.364     -1.936      0.053        -1.419     0.009
# C(FIPSST)[T.17]     -0.7447      0.223     -3.338      0.001        -1.182    -0.307
# C(FIPSST)[T.18]     -1.3525      0.280     -4.832      0.000        -1.901    -0.804
# C(FIPSST)[T.19]     -1.2702      0.317     -4.002      0.000        -1.892    -0.648
# C(FIPSST)[T.20]     -1.4553      0.308     -4.728      0.000        -2.059    -0.852
# C(FIPSST)[T.21]      0.0116      0.200      0.058      0.954        -0.380     0.403
# C(FIPSST)[T.22]      0.1790      0.206      0.868      0.386        -0.225     0.583
# C(FIPSST)[T.23]     -0.0493      0.378     -0.131      0.896        -0.790     0.691
# C(FIPSST)[T.24]      0.1567      0.266      0.589      0.556        -0.365     0.678
# C(FIPSST)[T.25]     -0.6965      0.322     -2.163      0.031        -1.328    -0.065
# C(FIPSST)[T.26]     -0.9463      0.276     -3.426      0.001        -1.488    -0.405
# C(FIPSST)[T.27]     -1.3702      0.284     -4.826      0.000        -1.927    -0.814
# C(FIPSST)[T.28]     -0.8849      0.311     -2.844      0.004        -1.495    -0.275
# C(FIPSST)[T.29]     -1.3336      0.269     -4.959      0.000        -1.861    -0.807
# C(FIPSST)[T.30]     -0.8440      0.437     -1.930      0.054        -1.701     0.013
# C(FIPSST)[T.31]     -0.4141      0.313     -1.324      0.185        -1.027     0.199
# C(FIPSST)[T.32]     -0.7558      0.506     -1.492      0.136        -1.748     0.237
# C(FIPSST)[T.33]      0.3599      0.427      0.842      0.400        -0.478     1.197
# C(FIPSST)[T.34]     -1.0058      0.299     -3.365      0.001        -1.592    -0.420
# C(FIPSST)[T.35]     -0.6701      0.345     -1.942      0.052        -1.347     0.006
# C(FIPSST)[T.36]      0.3330      0.250      1.334      0.182        -0.156     0.822
# C(FIPSST)[T.37]     -0.1008      0.194     -0.520      0.603        -0.481     0.279
# C(FIPSST)[T.38]     -1.2054      0.402     -2.999      0.003        -1.993    -0.418
# REAL_RATE            0.6906      0.030     23.159      0.000         0.632     0.749
# R_CTY_INT_DIFF      -0.0144      0.010     -1.381      0.167        -0.035     0.006
# GEN_REV           4.088e-07   1.08e-07      3.789      0.000      1.97e-07   6.2e-07
# TAX_EFFORT          -0.0093      0.011     -0.828      0.408        -0.031     0.013
# IGR_ST           -5.276e-07   1.93e-07     -2.737      0.006     -9.06e-07  -1.5e-07
# REAL_RATE_CHANGE     0.3479      0.030     11.516      0.000         0.289     0.407
# TOT_DEBT_OUTST   -9.623e-08   3.39e-08     -2.843      0.004     -1.63e-07 -2.99e-08
# ====================================================================================
# """

# %%
mod_dict[2].summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:         BIN_DEBT_ISSUE   No. Observations:                21816
# Model:                            GLM   Df Residuals:                    21808
# Model Family:                Binomial   Df Model:                            7
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -6968.6
# Date:                Sun, 15 Nov 2015   Deviance:                       13937.
# Time:                        18:32:20   Pearson chi2:                 1.94e+04
# No. Iterations:                   100
# ====================================================================================
#                        coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# Intercept            6.7757      0.647     10.477      0.000         5.508     8.043
# C(FIPSST)[T.4]       0.1093      0.286      0.382      0.703        -0.452     0.670
# C(FIPSST)[T.5]       0.3106      0.249      1.248      0.212        -0.177     0.798
# C(FIPSST)[T.6]       0.6799      0.209      3.252      0.001         0.270     1.090
# C(FIPSST)[T.8]       0.1130      0.257      0.439      0.660        -0.391     0.617
# C(FIPSST)[T.9]       1.1641      0.359      3.246      0.001         0.461     1.867
# C(FIPSST)[T.10]      0.3064      0.436      0.703      0.482        -0.548     1.160
# C(FIPSST)[T.12]      0.1207      0.209      0.577      0.564        -0.289     0.530
# C(FIPSST)[T.13]      0.6946      0.242      2.871      0.004         0.220     1.169
# C(FIPSST)[T.15]      0.3239      0.554      0.584      0.559        -0.762     1.410
# C(FIPSST)[T.16]     -0.0721      0.358     -0.202      0.840        -0.773     0.629
# C(FIPSST)[T.17]     -0.4041      0.222     -1.817      0.069        -0.840     0.032
# C(FIPSST)[T.18]     -0.0255      0.204     -0.125      0.901        -0.426     0.375
# C(FIPSST)[T.19]      0.1396      0.245      0.571      0.568        -0.340     0.619
# C(FIPSST)[T.20]     -0.1699      0.243     -0.698      0.485        -0.647     0.307
# C(FIPSST)[T.21]      0.0431      0.201      0.214      0.830        -0.352     0.438
# C(FIPSST)[T.22]      0.2213      0.207      1.070      0.285        -0.184     0.627
# C(FIPSST)[T.23]      0.2096      0.383      0.548      0.584        -0.541     0.960
# C(FIPSST)[T.24]      0.3325      0.284      1.172      0.241        -0.224     0.889
# C(FIPSST)[T.25]      0.1028      0.309      0.333      0.739        -0.502     0.708
# C(FIPSST)[T.26]      0.2164      0.213      1.018      0.309        -0.200     0.633
# C(FIPSST)[T.27]     -0.1300      0.223     -0.582      0.561        -0.568     0.308
# C(FIPSST)[T.28]      0.2456      0.259      0.948      0.343        -0.262     0.753
# C(FIPSST)[T.29]     -0.2389      0.208     -1.149      0.250        -0.646     0.169
# POVERTY             -6.2517      0.908     -6.882      0.000        -8.032    -4.471
# PC_SSI              -0.5077      0.239     -2.128      0.033        -0.975    -0.040
# DIVERSITY         7.415e-07   7.74e-08      9.579      0.000       5.9e-07  8.93e-07
# EMP_RES              2.8830      0.434      6.650      0.000         2.033     3.733
# MANU_RES            -3.2451      0.717     -4.527      0.000        -4.650    -1.840
# RETL_RES           -12.0897      1.934     -6.250      0.000       -15.881    -8.299
# SERV_RES            -0.2051      0.661     -0.310      0.756        -1.501     1.090
# BIN_REC             -0.0006      0.001     -0.641      0.521        -0.002     0.001
# OSRC_GAP             0.0493      0.299      0.165      0.869        -0.536     0.635
# REAL_RATE            0.6476      0.029     22.415      0.000         0.591     0.704
# R_CTY_INT_DIFF      -0.0169      0.012     -1.469      0.142        -0.039     0.006
# GEN_REV           4.723e-07   1.08e-07      4.355      0.000       2.6e-07  6.85e-07
# TAX_EFFORT          -0.0090      0.010     -0.863      0.388        -0.029     0.011
# IGR_ST           -5.613e-07   1.94e-07     -2.896      0.004     -9.41e-07 -1.81e-07
# REAL_RATE_CHANGE     0.3491      0.030     11.598      0.000         0.290     0.408
# TOT_DEBT_OUTST   -1.034e-07    3.4e-08     -3.044      0.002      -1.7e-07 -3.68e-08
# ====================================================================================
# """

# %%
mod_dict[3].summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:         BIN_DEBT_ISSUE   No. Observations:                21816
# Model:                            GLM   Df Residuals:                    21808
# Model Family:                Binomial   Df Model:                            7
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -6550.8
# Date:                Sun, 15 Nov 2015   Deviance:                       13102.
# Time:                        18:32:28   Pearson chi2:                 1.85e+04
# No. Iterations:                   100
# ====================================================================================
#                        coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# Intercept            6.5794      0.680      9.672      0.000         5.246     7.913
# C(FIPSST)[T.4]      -0.6879      0.354     -1.942      0.052        -1.382     0.006
# C(FIPSST)[T.5]       0.4253      0.331      1.286      0.199        -0.223     1.074
# C(FIPSST)[T.6]      -0.0636      0.298     -0.214      0.831        -0.647     0.520
# C(FIPSST)[T.8]       0.4276      0.388      1.103      0.270        -0.332     1.187
# C(FIPSST)[T.9]       1.2915      0.399      3.236      0.001         0.509     2.074
# C(FIPSST)[T.10]      0.3640      0.464      0.785      0.432        -0.544     1.272
# C(FIPSST)[T.12]     -0.0097      0.381     -0.025      0.980        -0.755     0.736
# C(FIPSST)[T.13]      0.7814      0.301      2.596      0.009         0.191     1.371
# C(FIPSST)[T.15]      0.2904      0.569      0.510      0.610        -0.825     1.406
# C(FIPSST)[T.16]     -0.0989      0.380     -0.260      0.795        -0.845     0.647
# C(FIPSST)[T.17]      0.0140      0.363      0.039      0.969        -0.698     0.726
# C(FIPSST)[T.18]      0.0637      0.356      0.179      0.858        -0.634     0.761
# C(FIPSST)[T.19]     -0.0659      0.419     -0.157      0.875        -0.887     0.755
# C(FIPSST)[T.20]     -0.1745      0.388     -0.450      0.653        -0.934     0.585
# C(FIPSST)[T.21]      0.9119      0.383      2.380      0.017         0.161     1.663
# RESPOP           -2.092e-07    1.9e-07     -1.098      0.272     -5.83e-07  1.64e-07
# RESPOP2          -1.408e-14   2.09e-14     -0.672      0.501     -5.51e-14   2.7e-14
# DENSITY           5.657e-05    2.9e-05      1.949      0.051     -3.24e-07     0.000
# POPGROWTH           -2.1783      1.311     -1.662      0.096        -4.747     0.390
# HSLD_PERS           -1.1547      0.214     -5.391      0.000        -1.575    -0.735
# PRE1940             -1.4343      0.409     -3.504      0.000        -2.236    -0.632
# PYOUNG              -0.3018      0.605     -0.499      0.618        -1.489     0.885
# PVT_SCH              4.2794      0.834      5.130      0.000         2.644     5.914
# POP65               -1.1573      0.812     -1.426      0.154        -2.748     0.434
# PC_INC           -8.201e-05   3.79e-06    -21.662      0.000     -8.94e-05 -7.46e-05
# POVERTY             -6.2107      0.890     -6.976      0.000        -7.956    -4.466
# PC_SSI              -0.5818      0.250     -2.327      0.020        -1.072    -0.092
# DIVERSITY         7.305e-07   7.75e-08      9.430      0.000      5.79e-07  8.82e-07
# EMP_RES              2.8514      0.438      6.516      0.000         1.994     3.709
# MANU_RES            -3.1292      0.718     -4.358      0.000        -4.536    -1.722
# RETL_RES           -11.7281      1.928     -6.084      0.000       -15.506    -7.950
# SERV_RES            -0.2343      0.663     -0.353      0.724        -1.534     1.066
# BIN_REC              9.0220      2.396      3.765      0.000         4.326    13.718
# OSRC_GAP             0.0513      0.299      0.171      0.864        -0.535     0.638
# REAL_RATE            0.6474      0.029     22.386      0.000         0.591     0.704
# R_CTY_INT_DIFF      -0.0177      0.012     -1.520      0.128        -0.040     0.005
# GEN_REV           4.743e-07   1.08e-07      4.380      0.000      2.62e-07  6.87e-07
# TAX_EFFORT           0.0010      0.004      0.253      0.800        -0.007     0.009
# IGR_ST           -5.805e-07   1.94e-07     -2.999      0.003      -9.6e-07 -2.01e-07
# REAL_RATE_CHANGE     0.3435      0.030     11.447      0.000         0.285     0.402
# TOT_DEBT_OUTST   -9.806e-08    3.4e-08     -2.887      0.004     -1.65e-07 -3.15e-08
# ====================================================================================
# """

# %%
dir(mod_dict[1])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_cache',
#  '_data_attr',
#  '_data_weights',
#  '_endog',
#  '_get_robustcov_results',
#  'aic',
#  'bic',
#  'bse',
#  'conf_int',
#  'cov_kwds',
#  'cov_params',
#  'cov_type',
#  'data_in_cache',
#  'deviance',
#  'df_model',
#  'df_resid',
#  'f_test',
#  'family',
#  'fit_history',
#  'fittedvalues',
#  'initialize',
#  'k_constant',
#  'llf',
#  'llnull',
#  'load',
#  'model',
#  'mu',
#  'nobs',
#  'normalized_cov_params',
#  'null',
#  'null_deviance',
#  'params',
#  'pearson_chi2',
#  'pinv_wexog',
#  'predict',
#  'pvalues',
#  'remove_data',
#  'resid_anscombe',
#  'resid_deviance',
#  'resid_pearson',
#  'resid_response',
#  'resid_working',
#  'save',
#  'scale',
#  'summary',
#  'summary2',
#  't_test',
#  'tvalues',
#  'use_t',
#  'wald_test']
